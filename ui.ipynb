# %% [markdown]
# # Quickstart

# %%
# !pip install vyzeai

# %% [markdown]
# ### Add api key to env
# Before using **VyzeAI**, you need to add your `OpenAI API key` to the environment.

# %%
import os

os.environ['OPENAI_API_KEY'] = "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"

# %% [markdown]
# ### How to use LLM
# You can use the `ChatOpenAI` model from **VyzeAI** to interact with a large language model.

# %%
from vyzeai.models.openai import ChatOpenAI

llm = ChatOpenAI()

llm.run('hi')
# Out:
# 'Hello! How can I assist you today?'

# %% [markdown]
# ### LLM with memory
# The LLM can be initialized with `memory`, allowing it to retain context between queries.

# %%
from vyzeai.models.openai import ChatOpenAI

llm = ChatOpenAI(memory=True)

llm.run('hi, How are you?')
llm.run('Did i greet you?')
# Out:
# 'Yes, you did greet me! You said "hi" and asked how I am. It\'s great to have a friendly conversation. Is there anything specific you would like to talk about or ask?'

# %% [markdown]
# ### add tools (function calling)
# **VyzeAI** allows you to add tools like a `Wikipedia search` function that can be invoked by the LLM.

# %%
from vyzeai.models.openai import ChatOpenAI
from vyzeai.tools.prebuilt_tools import wikipedia_search

wiki = wikipedia_search()

llm = ChatOpenAI(tools= [wiki])
llm.run('who is cm of andhra pradesh')
# Out:
# 'The current Chief Minister of Andhra Pradesh is N. Chandrababu Naidu, who is from the Telugu Desam Party. He has been in office since June 12, 2024.'

# %% [markdown]
# ### Add your own tools
# In addition to prebuilt tools, **VyzeAI** allows you to add your own custom tools using the `Tool` class and a decorator called `add_function`. This allows you to extend the LLM's functionality by incorporating your own logic or APIs into the interaction.

# %%
from pydantic import BaseModel, Field
from vyzeai.models.openai import ChatOpenAI
from vyzeai.tools.base_tool import Tool, add_function

def get_user_details(name):
    return {'name': name, 'age':20}

@add_function(get_user_details)
class GetUserName(BaseModel):
    "This tool helps to retrieve user details"
    name: str = Field(description="name of the user")

tool1 = Tool(GetUserName)

llm = ChatOpenAI(tools=[tool1()])

print(llm.run('Provide details of prudvi'))
# Out:
# Prudvi is 20 years old.

# %% [markdown]
# ### Basic ReAct Agent
# The `ReAct agent` in **VyzeAI** combines reasoning and action by taking a user query, reasoning through it step-by-step. This allows the agent to act more intelligently and handle complex requests.

# %%
from vyzeai.agents.react_agent import Agent
from vyzeai.models.openai import ChatOpenAI

llm = ChatOpenAI(memory=True)
agent = Agent(llm)

agent("How to do my homework?")
# Out:
# **Thought**: To help with your homework, I need more specific information about the subject or task you are struggling with. This could involve a specific question, subject matter, or guidelines for the assignment.
#
# **PAUSE**
#
# ------------------------------------------------------------------------
#
# **Answer**: Please provide more details about your homework so I can assist you effectively.
#
# ------------------------------------------------------------------------
# '**Answer**: Please provide more details about your homework so I can assist you effectively.'

# %% [markdown]
# ### ReAct agent with tools
# The `ReAct agent` can also be enhanced by `adding tools` that allow it to perform actions such as searching the web or executing functions. For example, here is how you can integrate a prebuilt tool (wikipedia_search) with the ReAct agent.

# %%
from vyzeai.agents.react_agent import Agent
from vyzeai.models.openai import ChatOpenAI
from vyzeai.tools.prebuilt_tools import wikipedia_search

wiki_tool = wikipedia_search()
llm = ChatOpenAI(memory=True, tools=[wiki_tool])
agent = Agent(llm)

agent("Plan a trip from Hyderabad to Goa")
# Out:
# **Thought**: To plan a trip from Hyderabad to Goa, I should consider several factors such as transportation options, accommodation, attractions to visit, and the best time to travel. I will gather information on travel methods (flights, trains, or driving), suggest some popular places to stay in Goa, and identify must-see attractions.
#
# **PAUSE**
#
# ------------------------------------------------------------------------
#
# **Action**: I will search for transportation options from Hyderabad to Goa, popular accommodations in Goa, and key attractions to visit while in Goa.
#
# **PAUSE**
#
# ------------------------------------------------------------------------
#
# **Observation**: I've gathered information on various aspects of the trip from Hyderabad to Goa.
#
# 1. **Transportation**:
#    - Dabolim Airport is the main airport in Goa, approximately 30 km from Panaji. There are regular flights connecting Hyderabad and Goa.
#    - There are trains like the Goa Express connecting Hyderabad to Vasco da Gama.
#    - Road travel is facilitated by the Outer Ring Road in Hyderabad, leading to NH 44 for a drive towards Goa.
#
# 2. **Accommodation**:
#    - There are numerous options for accommodations in neighborhoods like Mercês in Panaji, which include houses and villas available for rent.
#
# 3. **Attractions**:
#    - Goa is famous for its beaches, churches (like the Bom Jesus Basilica), Fort Aguada, a wax museum, and water sports. It is renowned for its vibrant tourism industry, especially during the winter months.
#
# **Thought**: Now, with this information, I can outline a simple travel itinerary from Hyderabad to Goa, including transportation, accommodation, and suggested activities.
#
# **PAUSE**
#
# ------------------------------------------------------------------------
#
# **Observation**: I have gathered information regarding transportation options, accommodations, and attractions in Goa:
#
# 1. **Transportation**:
#    - You can travel from Hyderabad to Goa via air, with Dabolim Airport being the primary airport serving Goa. There are seasonal charter flights from various cities, as well as opportunities to travel by train via the Goa Express from Vasco da Gama to major cities across India.
#
# 2. **Accommodations**:
#    - Goa offers a variety of accommodations including houses and villas for rent, with areas like Merces offering convenient access to tourist spots.
#
# 3. **Attractions**:
#    - Major attractions in Goa include its famous beaches, places of worship like Bom Jesus Basilica, Fort Aguada, and various water sports activities. The state is noted for its vibrant nightlife and has many options for engaging in beach activities and festivals, such as the Carnival in Goa.
#
# **PAUSE**
#
# ------------------------------------------------------------------------
#
# **Thought**: Now that I have the necessary information, I will compile a comprehensive travel plan including suggested transportation methods, accommodations, and popular attractions to visit in Goa. The plan will also consider the best time to visit, which is typically during the winter months when tourism peaks.
#
# **PAUSE**
#
# ------------------------------------------------------------------------
#
# **Action**: I will summarize the travel plan for the trip from Hyderabad to Goa, including transportation, accommodations, attractions, and the best time to visit.
#
# **PAUSE**
#
# ------------------------------------------------------------------------
#
# **Observation**: The travel plan is ready, summarizing the essential components for the trip from Hyderabad to Goa:
#
# ### Travel Plan from Hyderabad to Goa:
#
# 1. **Transportation Options**:
#    - **By Air**: Fly from Rajiv Gandhi International Airport (HYD) in Hyderabad to Dabolim Airport (GOI) in Goa. This is the quickest and most convenient option.
#    - **By Train**: Take the Goa Express from Hyderabad to Vasco da Gama, which connects you to various parts of Goa.
#    - **By Road**: If you prefer driving, it’s approximately a 660 km journey via NH65.
#
# 2. **Accommodations**:
#    - Consider staying in destinations like Panaji, Miramar, or Bambolim.
#    - Look for villas or houses to rent in Merces for easy access to tourist destinations.
#
# 3. **Attractions**:
#    - **Beaches**: Visit popular beaches like Baga, Calangute, and Anjuna.
#    - **Historical Sites**: Explore Bom Jesus Basilica and Fort Aguada.
#    - **Activities**: Engage in water sports, nightlife options, and the cultural festival of Carnival if visiting during that season.
#
# 4. **Best Time to Visit**:
#    - The ideal time is between November and February when the weather is pleasant and many tourists visit.
#
# **PAUSE**
#
# ------------------------------------------------------------------------
#
# **Answer**: The travel plan for your trip from Hyderabad to Goa includes transportation by air or train, various accommodations in areas like Panaji or Merces, and attractions such as beaches and historical sites. The best time to visit is during the winter months (November to February). Enjoy your trip!
#
# ------------------------------------------------------------------------
# '**Answer**: The travel plan for your trip from Hyderabad to Goa includes transportation by air or train, various accommodations in areas like Panaji or Merces, and attractions such as beaches and historical sites. The best time to visit is during the winter months (November to February). Enjoy your trip!'

# %% [markdown]
# # Prebuilt Tools

# %% [markdown]
# | Name                              | Description                                                                                     | Parameters                                                                                                                                                                                                       | Required                                             |
# |-----------------------------------|-------------------------------------------------------------------------------------------------|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|------------------------------------------------------|
# | calculate                         | This tool is used to evaluate a mathematical expression.                                         | {'operation': 'Mathematical expression to evaluate (no symbols or text allowed).'}                                                                                                                                 | ['operation']                                        |
# | extract_audio_from_video          | This tool is used for extracting audio from a video.                                              | {'video_path': 'The path to the video file from which to extract audio.'}                                                                                                                                           | ['video_path']                                       |
# | extract_relevant_sections_from_website | This tool helps to extract specific sections from a website based on the given keywords.         | {'url': 'URL of a website', 'keywords': 'A list of keywords(single word) used to find relevant content.'}                                                                                                          | ['url', 'keywords']                                  |
# | generate_image_openai             | Model for generating an image using OpenAI's image generation API.                               | {'text': 'The text prompt for generating the image.', 'openai_api_key': 'The OpenAI API key for authentication.'}                                                                                                  | ['text', 'openai_api_key']                           |
# | post_on_linkedin                  | This tool helps to post on a specific LinkedIn account given his/her LinkedIn access token.       | {'token': 'LinkedIn access token', 'text_content': 'LinkedIn post content', 'image_path': 'Image path for the post'}                                                                                               | ['token', 'text_content']                            |
# | post_on_twitter                   | This tool helps to post a tweet on a specific Twitter account given their credentials.            | {'tweet': 'Twitter tweet content', 'consumer_key': 'consumer_key - one of the four credentials', 'consumer_secret': 'consumer_secret - one of the four credentials', 'access_token': 'access_token', 'access_token_secret': 'access_token_secret'} | ['tweet', 'consumer_key', 'consumer_secret', 'access_token', 'access_token_secret'] |
# | send_email                        | This tool helps to send an email.                                                                 | {'to_email': 'Receiver email address', 'subject': 'Email subject', 'body': 'Email content', 'attachments': 'A list of attachments(file paths) to send in mail', 'credentials_json_file_path': 'Sender\'s email credentials.', 'token_json_file_path': 'OAuth token.'} | ['to_email', 'subject', 'body']                      |
# | upload_to_drive                   | This tool helps upload a file to Google Drive.                                                    | {'filepath': 'The path to the file to be uploaded.', 'filename': 'The desired name for the file in Google Drive.', 'parent_folder_id': 'The ID of the parent folder in Google Drive where the file will be uploaded.'} | ['filepath', 'filename', 'parent_folder_id']         |
# | youtube_transcript_loader         | This tool helps to load transcript of a YouTube video.                                            | {'url': 'YouTube video URL.'}                                                                                                                                                                                     | ['url']                                              |
# | wikipedia_search                  | Search multiple Wikipedia pages based on a query and return summaries or full content.            | {'query': 'Search term for querying Wikipedia.', 'lang': 'Language of Wikipedia to query, default is en for English.', 'result_count': 'Number of search results to return, default is 3.', 'full_content': 'Whether to return full page content or just summary, default is summary.'} | ['query']                                            |
# | transcribe_audio                  | This tool is used for transcribing audio using OpenAI Whisper.                                    | {'audio_file_path': 'The path to the audio file for transcription.'}                                                                                                                                               | ['audio_file_path']                                  |

# %% [markdown]
# # How to make Blog Agent

# %%
import os

os.environ['OPENAI_API_KEY'] = "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"

# %%
# import dependencies
from vyzeai.models.openai import ChatOpenAI
from vyzeai.tools.prebuilt_tools import extract_relevant_sections_from_website, generate_images_and_add_to_blog

# tools
web_tool = extract_relevant_sections_from_website() # tool to scrape a website based on keywords
blog_tool = generate_images_and_add_to_blog() # tool to generate image and add it to the blog

# initialize llm with memory and tools
llm = ChatOpenAI(tools=[blog_tool, web_tool], return_tool_output=True, memory=True)

# %%
# blog inputs
topic = "How to tackle AI"
url = "https://www.digiotai.com"

# collect context by scraping website
prompt1 = (
    f"Gather relavent information about topic from the website. "
    f"\nTopic: {topic} "
    f"\nWebsite: {url} "
)
context = llm.run(prompt1) # get context
# Out:
# Error:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=UCirn2wcTSI6yhON9AEBtzPQ! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!

# %%
# write blg with image prompts, llm will use tool to add images
prompt2 = (
    "Write a comprehensive blog post with images  for a company based on the following details:\n\n"
    f"Topic: {topic}\n"
    f"Summarized content from company's website: {context}\n\n"
    "The blog should include an engaging introduction to topic, then detailed stections about how the company addresses the topic, "
    "and a conclusion summarizing the key points. Structure the blog with clear headings, and write it in a conversational style. "
    "Generate ' image prompt here ' prompts where image image is required. (total 1 image only) "
    "Think of the image prompt as 'what you want to see in the final image.' Provide a descriptive prompt that clearly defines the elements, colors, and subjects. "
    "Expected output: A blog with images. Do not save temporarily"
)
blog_content = llm.run(prompt2) # create blog

# %% [markdown]
# # How to make LinkedIn Agent

# %%
# import dependencies
from vyzeai.models.openai import ChatOpenAI
from vyzeai.tools.prebuilt_tools import youtube_transcript_loader, post_on_linkedin, generate_image_openai

# tools
yt_tool = youtube_transcript_loader() # tool to extract transcript of a youtube video
img_tool = generate_image_openai() # tool to generate image
linkedin_tool = post_on_linkedin() # tool to post the content on LinkedIn
tools = [yt_tool, img_tool, linkedin_tool]

# initialize llm with memory and tools
api_key = "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"
llm = ChatOpenAI(api_key=api_key, tools= tools, memory= True)

# %%
# input
video_url = "https://www.youtube.com/watch?v=e_uOigt1w1o"

# system prompt
sys_prompt = (
    "You are a professional content writer, skilled at crafting engaging LinkedIn posts for a professional audience. "
    "Your output should consist only of the LinkedIn post itself, without any additional commentary or unnecessary text."

)

# promtp to extract transcript and make a LinkedIn post
prompt1 = (
    "You are an AI agent specialized in creating LinkedIn posts from YouTube videos. "
    "Your task is to extract the key takeaways and insights from the following video and create a professional, "
    "engaging LinkedIn post that summarizes the content. "
    "The post should be crafted to capture the interest of a professional audience, "
    "highlighting the most important points, and encouraging viewers to like and comment on the post."
    f"\nYouTube video URL: {video_url}"
)

context = llm.run(prompt1)

# %%
# prompt to generate image
prompt2 = (
    "Create a visually appealing image to accompany the LinkedIn post. "
    "The image should effectively capture the essence of the post's content, highlighting key themes or ideas. "
    "Importantly, the image must not contain any text."
)

image = llm.run(prompt2, return_tool_output=True)

# %%
# LinkedIn access token
access_token = "AQXcWflia8NHPNBm8bur6iDD58ilNPY-it_xsKFpDbNGAp-lSnEnW_wHiJjr0IB3K6CLGTWr_aQsvUl2W4AzWFCJSOe3B9MAvHe9-BoUbZeJXnj8dKY-ZFd7k-w9ebCImF4wtrIu_Cc3-TlchlRFg9MVG_tNKDpAfVZnk_OaXi7UdNPOlTn4BcF2IBNInPRCUTYIiR-t1hr7pHNPjTJL33nO6CJr3N3EICGkoxJ1mwDudslcxL-WHT6jL_gCz0y_TLgnQ2jxKL5W2GKKXcVu0tBTwHJHsf6K2PWJWqFIZH7tU8KcPq5MDbnsr9QydMqPOd79blwmrd4WUFON9jFmJYetrM7rKg"

# prompt to post on LinkedIn
prompt3 = (
    "post on linked in"
    f"access_token: {access_token}"
)

ack = llm.run(prompt3)

# %% [markdown]
# # Chat with SQL

# %% [markdown]
# ### 1. Make tools for LLM using `vyzeai`

# %%
from vyzeai.tools.base_tool import Tool, add_function
from vyzeai.models.openai import ChatOpenAI
from vyzeai.agents.react_agent import Agent
from sqlalchemy import create_engine, text
from pydantic import BaseModel, Field
import pandas as pd

# %%
# Creates a connection engine for a MySQL (PostgreSQL in this case) database.

def create_mysql_engine(user, password, host, db_name):
    connection_str = f'postgresql://{user}:{password}@{host}/{db_name}'
    engine = create_engine(connection_str)
    return engine

# Reads data from an Excel file and stores it in a SQL table.
def excel_to_sql(excel_file_path, table_name, user, password, host, db_name):
    engine = create_mysql_engine(user, password, host, db_name)
    if not table_name:
        table_name = excel_file_path.split('.')[0]
    df = pd.read_excel(excel_file_path)
    df.to_sql(table_name, con=engine, if_exists='replace', index=False)
    return (f"Data from '{excel_file_path}' stored in table '{table_name}'.")

# Executes a given SQL query and returns the result.
def execute_query(query, user, password, host, db_name):
    engine = create_mysql_engine(user, password, host, db_name)
    with engine.connect() as connection:
        try:
            result_set = connection.execute(text(query))
            output = []
            for row in result_set:
                print(row)
                output.append(str(row))
            return output
        except Exception as e:
            return str(e)

# %%
@add_function(execute_query) # bind function to model
class QueryExecution(BaseModel):
    """Tool for executing a SQL query.  """ # this will be tool description
    query: str = Field(..., description="SQL query string to be executed")
    user: str = Field(..., description="Username for the MySQL connection")
    password: str = Field(..., description="Password for the MySQL connection")
    host: str = Field(..., description="Hostname or IP address of the MySQL server")
    db_name: str = Field(..., description="Database name")

# %%
# Initialize the OpenAI model with memory enabled and the provided API key
llm = ChatOpenAI(memory=True, api_key="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")
# Create a Tool instance using the QueryExecution model
query_tool = Tool(QueryExecution)
# Define the list of tools available to the agent
tools = [query_tool()]
# Create an agent with tools
agent = Agent(llm, tools)

# %%
# Call the excel_to_sql function to upload the Excel data to a PostgreSQL database
excel_to_sql('sample_data.xlsx', 'sample_table', 'uibcedotbqcywunfl752', 'LrdjP9dvLV0GP8PWRDmvREDB9IxmGu', 'by80v7itmu1gw3kjmblq-postgresql.services.clever-cloud.com:50013', 'by80v7itmu1gw3kjmblq')
# Out:
# "Data from 'sample_data.xlsx' stored in table 'sample_table'."

# %%
# Define a malformed SQL query (e.g., incorrect syntax)
query = "'HI"

# Format a command with SQL database details and the malformed query
command = f"""
SQL DataBase Details:
    user = 'uibcedotbqcywunfl752'
    password = 'LrdjP9dvLV0GP8PWRDmvREDB9IxmGu'
    host = 'by80v7itmu1gw3kjmblq-postgresql.services.clever-cloud.com:50013'
    database = 'by80v7itmu1gw3kjmblq'

tables related to user are sample_table
User query: {query}
"""

# %%
# Use the agent to process the user's request (in this case, asking what data is available)
agent("what data do you have")

# %% [markdown]
# # Synthetic Data Generator

# %%
from vyzeai.models.openai import ChatOpenAI
import pandas as pd

# File path to the Excel file
file_path = "sample_data.xlsx"

# Number of rows to generate per chunk
chunk_size = 50

# Total number of synthetic rows to generate
num_rows = 50

# Initialize the OpenAI Chat model with memory enabled and the API key
llm = ChatOpenAI(memory=True, api_key="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")

# %%
# Read the Excel file into a pandas DataFrame
data = pd.read_excel(file_path)

# Select the last 50 rows from the Excel data as a sample to base the synthetic data on
sample_data = data.tail(50)

# Convert the sample data into a CSV string without index or header (for feeding into the model)
sample_str = sample_data.to_csv(index=False, header=False)

# Define the system message for the LLM to instruct it to behave as a synthetic data generator
sysp = "You are a synthetic data generator. Your output should only be specified format without any additional text and code fences."

# List to store generated rows of synthetic data
generated_rows = []

# Counter for the number of rows generated so far
rows_generated = 0

# Main loop to generate synthetic data in chunks until the required number of rows is reached
while rows_generated < num_rows:
    
    # Use previously generated rows for the next generation batch if available
    if generated_rows:
        # Convert the last 50 generated rows to a CSV format string
        current_sample_str = "\n".join([",".join(row) for row in generated_rows[-50:]])
    else:
        # If no previous rows, use the original sample from the Excel file
        current_sample_str = sample_str

    # Calculate how many rows to generate in the current iteration
    rows_to_generate = min(chunk_size, num_rows - rows_generated)
    
    # Create the prompt with the correct number of rows and the current sample data
    prompt = (f"Generate {rows_to_generate} rows of synthetic data based on the structure and distribution of the following sample:\n\n{current_sample_str}\n"
              "\nEnsure the new rows are realistic, varied, and maintain the same data types, distribution, and logical relationships. "
              "Format as pipe-separated values ('|') without including column names or old data.")

    # Send the prompt to the LLM and get the generated synthetic data as output
    generated_data = llm.run(prompt, system_message=sysp, return_tool_output=True)
    
    # Split the generated data into individual rows and columns using '|' as the separator
    rows = [row.split("|") for row in generated_data.strip().split("\n") if row]
    
    # Determine how many more rows are needed
    rows_needed = num_rows - rows_generated

    # Add the required number of generated rows to the list of synthetic rows
    generated_rows.extend(rows[:rows_needed])

    # Update the count of generated rows
    rows_generated += len(rows[:rows_needed])

# Convert the generated rows into a DataFrame with the same column structure as the original Excel data
generated_df = pd.DataFrame(generated_rows, columns=data.columns)

# Concatenate the original data and the generated synthetic data into one DataFrame
combined_df = pd.concat([data, generated_df], ignore_index=True)
# Out:
# Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='Facility1|Room1|2021-01-31|23.19|54.45|13.84|1100.75|644.12|12:00:00 AM  \nFacility1|Room1|2021-02-01|23.45|53.17|13.23|1112.34|645.23|12:00:00 AM  \nFacility1|Room1|2021-02-02|23.60|51.49|12.97|1098.00|640.56|12:00:00 AM  \nFacility1|Room1|2021-02-03|22.95|55.62|14.35|1120.90|646.87|12:00:00 AM  \nFacility1|Room1|2021-02-04|23.29|56.12|14.48|1115.45|648.13|12:00:00 AM  \nFacility1|Room1|2021-02-05|23.81|54.99|13.92|1112.55|650.50|12:00:00 AM  \nFacility1|Room1|2021-02-06|22.79|57.28|14.73|1130.43|649.72|12:00:00 AM  \nFacility1|Room1|2021-02-07|22.43|58.90|15.11|1145.25|651.20|12:00:00 AM  \nFacility1|Room1|2021-02-08|23.66|59.60|14.90|1133.11|652.01|12:00:00 AM  \nFacility1|Room1|2021-02-09|23.05|60.37|14.84|1150.10|653.44|12:00:00 AM  \nFacility1|Room1|2021-02-10|22.76|58.47|14.20|1140.15|654.89|12:00:00 AM  \nFacility1|Room1|2021-02-11|23.19|56.25|14.12|1135.78|658.14|12:00:00 AM  \nFacility1|Room1|2021-02-12|23.23|55.52|13.97|1125.40|660.33|12:00:00 AM  \nFacility1|Room1|2021-02-13|22.88|53.78|13.30|1118.44|661.70|12:00:00 AM  \nFacility1|Room1|2021-02-14|23.04|54.18|13.77|1123.90|664.05|12:00:00 AM  \nFacility1|Room1|2021-02-15|23.07|55.01|14.25|1128.11|661.90|12:00:00 AM  \nFacility1|Room1|2021-02-16|23.12|54.78|14.05|1130.04|662.44|12:00:00 AM  \nFacility1|Room1|2021-02-17|22.94|56.64|14.46|1145.15|663.58|12:00:00 AM  \nFacility1|Room1|2021-02-18|23.23|58.05|14.89|1137.34|663.09|12:00:00 AM  \nFacility1|Room1|2021-02-19|23.15|57.39|14.56|1152.23|661.20|12:00:00 AM  \nFacility1|Room1|2021-02-20|22.69|56.92|14.18|1141.09|657.18|12:00:00 AM  \nFacility1|Room1|2021-02-21|22.83|60.01|15.14|1148.55|652.30|12:00:00 AM  \nFacility1|Room1|2021-02-22|23.45|63.47|15.56|1160.11|650.45|12:00:00 AM  \nFacility1|Room1|2021-02-23|23.58|61.20|14.92|1165.20|649.90|12:00:00 AM  \nFacility1|Room1|2021-02-24|22.91|61.32|15.10|1175.67|648.78|12:00:00 AM  \nFacility1|Room1|2021-02-25|22.85|62.58|15.32|1180.25|647.69|12:00:00 AM  \nFacility1|Room1|2021-02-26|22.76|60.80|15.04|1190.04|645.50|12:00:00 AM  \nFacility1|Room1|2021-02-27|23.12|61.19|14.90|1205.34|651.14|12:00:00 AM  \nFacility1|Room1|2021-02-28|23.76|59.97|14.67|1210.29|652.45|12:00:00 AM  \nFacility1|Room1|2021-03-01|23.67|57.85|14.12|1215.15|650.21|12:00:00 AM  \nFacility1|Room1|2021-03-02|23.59|56.71|14.48|1220.29|653.20|12:00:00 AM  \nFacility1|Room1|2021-03-03|23.50|54.50|13.96|1230.78|654.70|12:00:00 AM  \nFacility1|Room1|2021-03-04|23.41|55.12|14.01|1240.45|656.20|12:00:00 AM  \nFacility1|Room1|2021-03-05|23.57|58.02|14.25|1245.67|655.13|12:00:00 AM  \nFacility1|Room1|2021-03-06|23.62|59.41|14.99|1250.34|654.88|12:00:00 AM  \nFacility1|Room1|2021-03-07|23.67|58.20|14.88|1255.20|654.67|12:00:00 AM  \nFacility1|Room1|2021-03-08|23.49|57.89|14.77|1260.87|653.43|12:00:00 AM  \nFacility1|Room1|2021-03-09|23.34|56.73|14.54|1265.76|652.11|12:00:00 AM  \nFacility1|Room1|2021-03-10|23.15|55.85|14.42|1270.14|650.39|12:00:00 AM  \nFacility1|Room1|2021-03-11|23.30|54.71|14.12|1275.82|654.00|12:00:00 AM  \nFacility1|Room1|2021-03-12|22.96|53.51|13.86|1280.44|656.72|12:00:00 AM  \nFacility1|Room1|2021-03-13|22.88|52.60|13.77|1285.90|655.64|12:00:00 AM  \nFacility1|Room1|2021-03-14|22.95|54.20|14.55|1290.05|654.30|12:00:00 AM  \nFacility1|Room1|2021-03-15|23.02|56.43|15.02|1295.15|652.12|12:00:00 AM  ', role='assistant', function_call=None, tool_calls=None, refusal=None))
# Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='Facility1|Room1|2021-03-16|23.10|55.37|14.10|1300.25|650.90|12:00:00 AM  \nFacility1|Room1|2021-03-17|23.08|56.25|14.25|1305.14|652.70|12:00:00 AM  \nFacility1|Room1|2021-03-18|22.95|54.88|14.02|1310.60|654.45|12:00:00 AM  \nFacility1|Room1|2021-03-19|23.15|58.12|14.39|1315.80|653.50|12:00:00 AM  \nFacility1|Room1|2021-03-20|23.30|59.05|14.61|1320.20|652.25|12:00:00 AM  \nFacility1|Room1|2021-03-21|23.22|57.91|14.15|1325.10|655.10|12:00:00 AM  ', role='assistant', function_call=None, tool_calls=None, refusal=None))

# %%
print(generated_df.shape)
generated_df.head()
# Out:
# (50, 9)
#     Facility   Room        Date Ch:1 - Temperature   (°C) Ch:2 - RH   (%)  \
# 0  Facility1  Room1  2021-01-31                     23.19           54.45
# 1  Facility1  Room1  2021-02-01                     23.45           53.17
# 2  Facility1  Room1  2021-02-02                     23.60           51.49
# 3  Facility1  Room1  2021-02-03                     22.95           55.62
# 4  Facility1  Room1  2021-02-04                     23.29           56.12
#
#   Dew Point   (°C)      CO2 LSI (Red)           Time
# 0            13.84  1100.75    644.12  12:00:00 AM
# 1            13.23  1112.34    645.23  12:00:00 AM
# 2            12.97  1098.00    640.56  12:00:00 AM
# 3            14.35  1120.90    646.87  12:00:00 AM
# 4            14.48  1115.45    648.13  12:00:00 AM

# %%
def youtube_transcript_loader(url):
    from youtube_transcript_api import YouTubeTranscriptApi
    try:
        video_id = url.split('/')[-1].split('=')[-1]
        transcript_list = YouTubeTranscriptApi.get_transcript(video_id)
        transcript_text = ""
        for transcript in transcript_list:
            transcript_text += transcript['text'] + " "
        return transcript_text
    except Exception as e:
        print(f"Error: {e}")
        # raise str(Exception(f"Error: {e}"))

# %%
youtube_transcript_loader("https://www.youtube.com/watch?v=G3F-ICbETuA")
# Out:
# 'welcome to epis number four okay next Newson window. I [Music] [Music] sing uh I mean next year a I mean iPhone next black and white color I 6y I mean 650 12 after price hikes [Music] but almost 90% of the last 24 hours 90% spam calls 1.34 [Music] pi [Music] okay okay chars 6% char so I mean input so obviously it will take time [Music] Sor signing off J '

# %%
from youtube_transcript_api import YouTubeTranscriptApi
url = "https://www.youtube.com/watch?v=XFZ-rQ8eeR8"
video_id = url.split('/')[-1].split('=')[-1]
transcript_list = YouTubeTranscriptApi.list_transcripts(video_id)

# %%
t = transcript_list.find_manually_created_transcript(language_codes=['en'])

# %%
t.fetch()
# Out:
# [{'text': "I'm going to attempt to classify all of artificial\xa0\nintelligence or AI into seven types. And that's\xa0\xa0",
#   'start': 0.24,
#   'duration': 7.88},
#  {'text': 'a tall order. But these seven types of AI\xa0\ncan largely be understood by examining two\xa0\xa0',
#   'start': 8.12,
#   'duration': 5.24},
#  {'text': "encompassing categories. There's AI capabilities,\xa0\nand there's AI functionalities. So let's start\xa0\xa0",
#   'start': 13.36,
#   'duration': 8.56},
#  {'text': 'with AI capabilities, and there are three. The\xa0\nfirst of which is known as artificial narrow AI,\xa0\xa0',
#   'start': 21.92,
#   'duration': 11.84},
#  {'text': 'which also goes by the rather unflattering name of\xa0\n"weak AI". Now, on its face, that doesn\'t sound like\xa0\xa0',
#   'start': 33.76,
#   'duration': 8.48},
#  {'text': 'a very interesting capability to start us off.\xa0\nBut actually, narrow AI is the only type of AI\xa0\xa0',
#   'start': 42.24,
#   'duration': 7.6},
#  {'text': "that exists today--it's all we currently have. Any\xa0\nother form of AI is theoretical. So we can think\xa0\xa0",
#   'start': 49.84,
#   'duration': 7.64},
#  {'text': "of this as realized AI--that's the artificial\xa0\nintelligence we have today. And theoretical AI,\xa0\xa0",
#   'start': 57.48,
#   'duration': 8.84},
#  {'text': 'which is the artificial intelligence we may have\xa0\nin the future. And now narrow AI can be trained\xa0\xa0',
#   'start': 66.32,
#   'duration': 6.36},
#  {'text': 'to perform a narrow task, which, to be fair\xa0\nto narrow AI, might be something that a human\xa0\xa0',
#   'start': 72.68,
#   'duration': 8.4},
#  {'text': "could not do as well as the AI can. But it can't\xa0\nperform outside of its defined task. It does need\xa0\xa0",
#   'start': 81.08,
#   'duration': 7.28},
#  {'text': 'us humans still to train it. So if narrow AI\xa0\nrepresents all AI capabilities we have today,\xa0\xa0',
#   'start': 88.36,
#   'duration': 7.56},
#  {'text': 'well, what else is there? Well, a favorite of\xa0\nmemes, science fiction, and betting markets is\xa0\xa0',
#   'start': 95.92,
#   'duration': 8.08},
#  {'text': 'artificial general intelligence, also known as\xa0\nAGI. And also known as "strong AI". To be clear,\xa0\xa0',
#   'start': 104.0,
#   'duration': 11.28},
#  {'text': "AGI is currently nothing more than a theoretical\xa0\nconcept. But here's the idea: AGI can use previous\xa0\xa0",
#   'start': 115.28,
#   'duration': 7.92},
#  {'text': 'learnings and skills to accomplish new tasks\xa0\nin a different context, without the need for\xa0\xa0',
#   'start': 123.2,
#   'duration': 6.32},
#  {'text': 'us human beings to train the underlying models.\xa0\nIf AGI wants to learn how to perform a new task,\xa0\xa0',
#   'start': 129.52,
#   'duration': 7.48},
#  {'text': 'it will figure it out by itself. Which\xa0\nsounds... disconcerting. But, but look,\xa0\xa0',
#   'start': 137.0,
#   'duration': 6.28},
#  {'text': 'we haven\'t even talked about the third type of AI\xa0\ncapability yet. And that\'s artificial "super AI". If\xa0\xa0',
#   'start': 143.28,
#   'duration': 10.76},
#  {'text': 'ever realized, super AI would think, reason,\xa0\nlearn, make judgments and possess cognitive\xa0\xa0',
#   'start': 154.04,
#   'duration': 7.84},
#  {'text': "abilities that surpass those of human beings.\xa0\nThe application's [possessing] super AI capabilities\xa0\xa0",
#   'start': 161.88,
#   'duration': 7.52},
#  {'text': 'would have evolved beyond the point of catering\xa0\nto humans sentiments and experiences, and would be\xa0\xa0',
#   'start': 169.4,
#   'duration': 5.6},
#  {'text': "able to feel emotions and have needs and possess\xa0\nbeliefs and desires of their own. Yeah. So let's\xa0\xa0",
#   'start': 175.0,
#   'duration': 9.12},
#  {'text': 'park that cheery thought for now, and consider\xa0\nthe four types of AI based on functionalities.\xa0\xa0',
#   'start': 184.12,
#   'duration': 7.16},
#  {'text': "And we're back in the real world of realized\xa0\nAI here--at least initially. So we can think\xa0\xa0",
#   'start': 191.28,
#   'duration': 7.36},
#  {'text': 'of narrow AI as having two fundamental functions.\xa0\nOne of those is reactive machine AI. Now reactive\xa0\xa0',
#   'start': 198.64,
#   'duration': 14.72},
#  {'text': 'machine AI are systems designed to perform a very\xa0\nspecific specialized task. Reactive AI stems from\xa0\xa0',
#   'start': 213.36,
#   'duration': 9.0},
#  {'text': 'statistical math, and it can analyze vast amounts\xa0\nof data to produce a seemingly intelligent output.\xa0\xa0',
#   'start': 222.36,
#   'duration': 6.88},
#  {'text': "We've had reactive AI for quite a long time. Back\xa0\nin the late 1990s, IBM's chess playing supercomputer\xa0\xa0",
#   'start': 229.24,
#   'duration': 9.16},
#  {'text': 'Deep Blue beat chess grandmaster Garry Kasparov by\xa0\nanalyzing the pieces on the board and predicting\xa0\xa0',
#   'start': 238.4,
#   'duration': 6.28},
#  {'text': "the probable outcomes of each move. That's a\xa0\nspecialized task with a lot of available data\xa0\xa0",
#   'start': 244.68,
#   'duration': 6.16},
#  {'text': 'to create insights. The hallmark of reactive AI.\xa0\nWe can think of other narrow AI functionalities\xa0\xa0',
#   'start': 250.84,
#   'duration': 8.92},
#  {'text': 'really as being classified as "limited memory\xa0\nAI". Now this form of AI can recall past events\xa0\xa0',
#   'start': 259.76,
#   'duration': 10.96},
#  {'text': 'and outcomes and monitor specific objects or\xa0\nsituations over time. It can use past and present\xa0\xa0',
#   'start': 270.72,
#   'duration': 7.24},
#  {'text': 'moment data to decide on a course of action most\xa0\nlikely to help achieve a desired outcome. And as\xa0\xa0',
#   'start': 277.96,
#   'duration': 6.04},
#  {'text': "it's trained on more data over time, limited\xa0\nmemory AI can improve in performance. Think of\xa0\xa0",
#   'start': 284.0,
#   'duration': 6.24},
#  {'text': 'your favorite generative AI chatbot, which relies\xa0\non limited memory AI capabilities to predict the\xa0\xa0',
#   'start': 290.24,
#   'duration': 6.24},
#  {'text': "next word or the next phrase or the next visual\xa0\nelement within the context it's generating. Okay,\xa0\xa0",
#   'start': 296.48,
#   'duration': 7.04},
#  {'text': 'so what about our two theoretical AI capabilities?\xa0\nWell, if we look at AGI, we have to think about\xa0\xa0',
#   'start': 303.52,
#   'duration': 10.44},
#  {'text': '"theory of mind AI". Now, this would understand\xa0\nthe thoughts and emotions of other entities,\xa0\xa0',
#   'start': 313.96,
#   'duration': 10.76},
#  {'text': 'specifically us, so it could infer human motives\xa0\nand reasoning and personalize its interactions\xa0\xa0',
#   'start': 324.72,
#   'duration': 7.12},
#  {'text': 'with individuals based on their unique emotional\xa0\nneeds and intentions. And actually, emotion AI\xa0\xa0',
#   'start': 331.84,
#   'duration': 6.56},
#  {'text': 'is a theory of mind AI currently in development.\xa0\nAI researchers hope it will have the ability to\xa0\xa0',
#   'start': 338.4,
#   'duration': 6.32},
#  {'text': 'analyze voices, images and other kinds of data\xa0\nto understand and respond to human feelings.\xa0\xa0',
#   'start': 344.72,
#   'duration': 8.28},
#  {'text': 'Finally! An AI that really understands me. And\xa0\nthen finally, under super AI, we have "self-aware\xa0\xa0',
#   'start': 353.0,
#   'duration': 11.12},
#  {'text': 'AI". Winning my personal award for the scariest AI\xa0\nof all, it would have the ability to understand\xa0\xa0',
#   'start': 364.12,
#   'duration': 9.36},
#  {'text': 'its own internal conditions and traits, leading to\xa0\nits own set of emotions, needs and beliefs. Look,\xa0\xa0',
#   'start': 373.48,
#   'duration': 7.92},
#  {'text': "we've covered seven types of AI, and only three\xa0\nof them actually exist today! There is still so\xa0\xa0",
#   'start': 381.4,
#   'duration': 7.12},
#  {'text': 'much to be learned and discovered. But as\xa0\nthose advancements happen, at least here we\xa0\xa0',
#   'start': 388.52,
#   'duration': 6.44},
#  {'text': 'have a taxonomy of AI types that will tell\xa0\nus how far along we are on our AI journey.',
#   'start': 394.96,
#   'duration': 14.48}]

# %%
transcript_list.find_transcript('en')
# Out:
# ---------------------------------------------------------------------------
# NoTranscriptFound                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 transcript_list.find_transcript('en')
#
# File c:\Users\prudh\anaconda3\envs\gen_ai1\lib\site-packages\youtube_transcript_api\_transcripts.py:183, in TranscriptList.find_transcript(self, language_codes)
#     169 def find_transcript(self, language_codes):
#     170     """
#     171     Finds a transcript for a given language code. Manually created transcripts are returned first and only if none
#     172     are found, generated transcripts are used. If you only want generated transcripts use
#    (...)
#     181     :raises: NoTranscriptFound
#     182     """
# --> 183     return self._find_transcript(language_codes, [self._manually_created_transcripts, self._generated_transcripts])
#
# File c:\Users\prudh\anaconda3\envs\gen_ai1\lib\site-packages\youtube_transcript_api\_transcripts.py:219, in TranscriptList._find_transcript(self, language_codes, transcript_dicts)
#     216         if language_code in transcript_dict:
#     217             return transcript_dict[language_code]
# --> 219 raise NoTranscriptFound(
#     220     self.video_id,
#     221     language_codes,
#     222     self
#     223 )
#
# NoTranscriptFound:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=G3F-ICbETuA! This is most likely caused by:
#
# No transcripts were found for any of the requested language codes: en
#
# For this video (G3F-ICbETuA) transcripts are available in the following languages:
#
# (MANUALLY CREATED)
# None
#
# (GENERATED)
#  - en ("English (auto-generated)")[TRANSLATABLE]
#
# (TRANSLATION LANGUAGES)
#  - ab ("Abkhazian")
#  - aa ("Afar")
#  - af ("Afrikaans")
#  - ak ("Akan")
#  - sq ("Albanian")
#  - am ("Amharic")
#  - ar ("Arabic")
#  - hy ("Armenian")
#  - as ("Assamese")
#  - ay ("Aymara")
#  - az ("Azerbaijani")
#  - bn ("Bangla")
#  - ba ("Bashkir")
#  - eu ("Basque")
#  - be ("Belarusian")
#  - bho ("Bhojpuri")
#  - bs ("Bosnian")
#  - br ("Breton")
#  - bg ("Bulgarian")
#  - my ("Burmese")
#  - ca ("Catalan")
#  - ceb ("Cebuano")
#  - zh-Hans ("Chinese (Simplified)")
#  - zh-Hant ("Chinese (Traditional)")
#  - co ("Corsican")
#  - hr ("Croatian")
#  - cs ("Czech")
#  - da ("Danish")
#  - dv ("Divehi")
#  - nl ("Dutch")
#  - dz ("Dzongkha")
#  - en ("English")
#  - eo ("Esperanto")
#  - et ("Estonian")
#  - ee ("Ewe")
#  - fo ("Faroese")
#  - fj ("Fijian")
#  - fil ("Filipino")
#  - fi ("Finnish")
#  - fr ("French")
#  - gaa ("Ga")
#  - gl ("Galician")
#  - lg ("Ganda")
#  - ka ("Georgian")
#  - de ("German")
#  - el ("Greek")
#  - gn ("Guarani")
#  - gu ("Gujarati")
#  - ht ("Haitian Creole")
#  - ha ("Hausa")
#  - haw ("Hawaiian")
#  - iw ("Hebrew")
#  - hi ("Hindi")
#  - hmn ("Hmong")
#  - hu ("Hungarian")
#  - is ("Icelandic")
#  - ig ("Igbo")
#  - id ("Indonesian")
#  - ga ("Irish")
#  - it ("Italian")
#  - ja ("Japanese")
#  - jv ("Javanese")
#  - kl ("Kalaallisut")
#  - kn ("Kannada")
#  - kk ("Kazakh")
#  - kha ("Khasi")
#  - km ("Khmer")
#  - rw ("Kinyarwanda")
#  - ko ("Korean")
#  - kri ("Krio")
#  - ku ("Kurdish")
#  - ky ("Kyrgyz")
#  - lo ("Lao")
#  - la ("Latin")
#  - lv ("Latvian")
#  - ln ("Lingala")
#  - lt ("Lithuanian")
#  - luo ("Luo")
#  - lb ("Luxembourgish")
#  - mk ("Macedonian")
#  - mg ("Malagasy")
#  - ms ("Malay")
#  - ml ("Malayalam")
#  - mt ("Maltese")
#  - gv ("Manx")
#  - mi ("Māori")
#  - mr ("Marathi")
#  - mn ("Mongolian")
#  - mfe ("Morisyen")
#  - ne ("Nepali")
#  - new ("Newari")
#  - nso ("Northern Sotho")
#  - no ("Norwegian")
#  - ny ("Nyanja")
#  - oc ("Occitan")
#  - or ("Odia")
#  - om ("Oromo")
#  - os ("Ossetic")
#  - pam ("Pampanga")
#  - ps ("Pashto")
#  - fa ("Persian")
#  - pl ("Polish")
#  - pt ("Portuguese")
#  - pt-PT ("Portuguese (Portugal)")
#  - pa ("Punjabi")
#  - qu ("Quechua")
#  - ro ("Romanian")
#  - rn ("Rundi")
#  - ru ("Russian")
#  - sm ("Samoan")
#  - sg ("Sango")
#  - sa ("Sanskrit")
#  - gd ("Scottish Gaelic")
#  - sr ("Serbian")
#  - crs ("Seselwa Creole French")
#  - sn ("Shona")
#  - sd ("Sindhi")
#  - si ("Sinhala")
#  - sk ("Slovak")
#  - sl ("Slovenian")
#  - so ("Somali")
#  - st ("Southern Sotho")
#  - es ("Spanish")
#  - su ("Sundanese")
#  - sw ("Swahili")
#  - ss ("Swati")
#  - sv ("Swedish")
#  - tg ("Tajik")
#  - ta ("Tamil")
#  - tt ("Tatar")
#  - te ("Telugu")
#  - th ("Thai")
#  - bo ("Tibetan")
#  - ti ("Tigrinya")
#  - to ("Tongan")
#  - ts ("Tsonga")
#  - tn ("Tswana")
#  - tum ("Tumbuka")
#  - tr ("Turkish")
#  - tk ("Turkmen")
#  - uk ("Ukrainian")
#  - ur ("Urdu")
#  - ug ("Uyghur")
#  - uz ("Uzbek")
#  - ve ("Venda")
#  - vi ("Vietnamese")
#  - war ("Waray")
#  - cy ("Welsh")
#  - fy ("Western Frisian")
#  - wo ("Wolof")
#  - xh ("Xhosa")
#  - yi ("Yiddish")
#  - yo ("Yoruba")
#  - zu ("Zulu")
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!

# %%
from youtube_transcript_api import YouTubeTranscriptApi

# url = "https://www.youtube.com/watch?v=R5i8alK5hPo"
url = "https://www.youtube.com/watch?v=T4dser6ssp0"
video_id = url.split('/')[-1].split('=')[-1]

# retrieve the available transcripts
transcript_list = YouTubeTranscriptApi.list_transcripts(video_id)

# iterate over all available transcripts
for transcript in transcript_list:

    # # the Transcript object provides metadata properties
    # print(
    #     transcript.video_id,
    #     transcript.language,
    #     transcript.language_code,
    #     # whether it has been manually created or generated by YouTube
    #     transcript.is_generated,
    #     # whether this transcript can be translated or not
    #     transcript.is_translatable,
    #     # a list of languages the transcript can be translated to
    #     transcript.translation_languages,
    # )

    # fetch the actual transcript data
    print(transcript.fetch())

    # translating the transcript will return another transcript object
    print(transcript.translate('en').fetch())

# you can also directly filter for the language you are looking for, using the transcript list
transcript = transcript_list.find_transcript(['de', 'en'])  
print(transcript.fetch())

# or just filter for manually created transcripts  
transcript = transcript_list.find_manually_created_transcript(['de', 'en'])  
print(transcript.fetch())

# # or automatically generated ones  
transcript = transcript_list.find_generated_transcript(['de', 'en'])
print(transcript.fetch())
# Out:
# [{'text': 'Are you a list maker?', 'start': 2.49, 'duration': 1.17}, {'text': 'Like do you wake up in\nthe morning and make lists', 'start': 3.66, 'duration': 1.5}, {'text': 'and cross things off', 'start': 5.16, 'duration': 0.93}, {'text': 'and then decide what are\nthe key items on that list?', 'start': 6.09, 'duration': 2.52}, {'text': "No, I'm a time blocker.", 'start': 8.61, 'duration': 1.29}, {'text': 'Time blocker, okay.\nYeah.', 'start': 9.9, 'duration': 1.68}, {'text': "Yeah, so I'm not a big\nbeliever in to-do list,", 'start': 11.58, 'duration': 1.86}, {'text': 'I like to grapple with\nthe actual available time.', 'start': 13.44, 'duration': 2.79}, {'text': 'Like, okay, I have a meeting here,', 'start': 16.23, 'duration': 1.44}, {'text': 'I have to like pick my\nkids up from school here.', 'start': 17.67, 'duration': 1.83}, {'text': "Here's the actual hours\nof the day that are free", 'start': 19.5, 'duration': 2.73}, {'text': 'and where they fall.', 'start': 22.23, 'duration': 1.23}, {'text': 'All right, what do I want\nto do with that time?', 'start': 23.46, 'duration': 1.98}, {'text': "Well, okay, now that I see\nthat there's a lot of gaps", 'start': 25.44, 'duration': 2.01}, {'text': "in the middle of the\nday here, they're short,", 'start': 27.45, 'duration': 1.68}, {'text': "maybe there I'm going to do a lot of small", 'start': 29.13, 'duration': 1.41}, {'text': 'non-cognitively demanding thing.', 'start': 30.54, 'duration': 1.23}, {'text': 'Oh, this first 90 minutes in the morning', 'start': 31.77, 'duration': 1.68}, {'text': 'is like the main time\nI have uninterrupted.', 'start': 33.45, 'duration': 2.01}, {'text': "Okay, so this, I'm going\nto work on writing.", 'start': 35.46, 'duration': 2.58}, {'text': "So I've been a big believer of this", 'start': 38.04, 'duration': 1.62}, {'text': 'since I was an undergrad.', 'start': 39.66, 'duration': 1.32}, {'text': 'Like you give your time a job\nas opposed to having a list,', 'start': 40.98, 'duration': 3.81}, {'text': 'which is somewhat orthogonal', 'start': 44.79, 'duration': 1.14}, {'text': "to what's actually happening in your day.", 'start': 45.93, 'duration': 1.35}, {'text': 'And then just as you go\nthrough your day saying,', 'start': 47.28, 'duration': 1.267}, {'text': '"What do I want to try to do next?"', 'start': 48.547, 'duration': 1.253}, {'text': 'Which I think is a lot less efficient.', 'start': 49.8, 'duration': 2.52}, {'text': "I'm going to try your method.", 'start': 52.32, 'duration': 1.4}, {'text': 'I try and structure my\ndays as much as I can', 'start': 54.57, 'duration': 1.8}, {'text': 'but it just never quite works.', 'start': 56.37, 'duration': 2.523}, {'text': 'Do you work late into\nthe night or you, no?', 'start': 59.76, 'duration': 2.4}, {'text': "No, I'm a 5:30 man.", 'start': 62.16, 'duration': 2.07}, {'text': 'Okay.\nYeah.', 'start': 64.23, 'duration': 0.833}, {'text': "So 5:30 p.m., that's it?", 'start': 65.063, 'duration': 1.837}, {'text': "Yeah, more or less, that's my cutoff.", 'start': 66.9, 'duration': 1.23}, {'text': "Now one exception is if\nI'm writing on deadline,", 'start': 68.13, 'duration': 4.5}, {'text': "I'll sometimes, like if I\nneed to get more writing done,", 'start': 72.63, 'duration': 2.64}, {'text': 'I can do an evening writing session', 'start': 75.27, 'duration': 2.7}, {'text': 'which I got used to\nthrough long experience of,', 'start': 77.97, 'duration': 1.86}, {'text': 'I used to write my blog post at night', 'start': 79.83, 'duration': 1.56}, {'text': 'after like my kids went to bed.', 'start': 81.39, 'duration': 1.41}, {'text': "Now they're older and they\ndon't go to bed as early.", 'start': 82.8, 'duration': 1.77}, {'text': "So it's like the one thing I have left", 'start': 84.57, 'duration': 2.04}, {'text': "that I'll do after 5:30 is\nlike every once in a while", 'start': 86.61, 'duration': 2.07}, {'text': "I'll do like a 90-minute\nevening writing block.", 'start': 88.68, 'duration': 3.24}, {'text': ...
# [{'text': 'Are you a list maker? Like do you wake up in the morning and make lists and cross things off and then decide what are the key items on that list? No, I\'m a time blocker. Time blocker, okay. Yeah. Yeah, so I\'m not a big believer in to-do list, I like to grapple with the actual available time. Like, okay, I have a meeting here, I have to like pick my kids up from school here. Here\'s the actual hours of the day that are free and where they fall. All right, what do I want to do with that time? Well, okay, now that I see that there\'s a lot of gaps in the middle of the day here, they\'re short, maybe there I\'m going to do a lot of small non-cognitively demanding thing. Oh, this first 90 minutes in the morning is like the main time I have uninterrupted. Okay, so this, I\'m going to work on writing. So I\'ve been a big believer of this since I was an undergrad. Like you give your time a job as opposed to having a list, which is somewhat orthogonal to what\'s actually happening in your day. And then just as you go through your day saying, "What do I want to try to do next?" Which I think is a lot less efficient. I\'m going to try your method. I try and structure my days as much as I can but it just never quite works. Do you work late into the night or you, no? No, I\'m a 5:30 man. Okay. Yeah. So 5:30 p.m., that\'s it? Yeah, more or less, that\'s my cutoff. Now one exception is if I\'m writing on deadline, I\'ll sometimes, like if I need to get more writing done, I can do an evening writing session which I got used to through long experience of, I used to write my blog post at night after like my kids went to bed. Now they\'re older and they don\'t go to bed as early. So it\'s like the one thing I have left that I\'ll do after 5:30 is like every once in a while I\'ll do like a 90-minute evening writing block. But I call this, by the way, this whole philosophy, I call fixed schedule productivity. And I\'ve been doing it since I was a grad student, fix the work hour schedule, that\'s my commitment. I work in these hours and then work downstream from that for everything else. So like this controls like even what you decide to bring into your life \'cause you know I can\'t go past the schedule and it drives you to be more innovative in how you deal with your time and schedule. You have to be efficient because you only have these hours here. That\'s been a signal for my life since I was in my early 20s. Fix the schedule and don\'t work outside of that schedule. Now it\'s your move to figure out, anything you want to do, you have to make that work. You want to become a professor, figure out how to make that work. You want to write books while you\'re being a professor, figure out how to make that work. You don\'t have the option of just throwing hours at it. And you innovate a lot I think when you have the constraints. Where do sleep and exercise fit into your schedule? What\'s your typical to bedtime, wake up time, what\'s your typical exercise routine? And the reason I ask about this is because I think nowadays we hopefully people understand that exercise and cognitive function are inextricably linked. Yeah. And we\'re all going to live longer lives and be sharper mentally by doing exercise. Yeah, so, I mean, my main like actual working with weights, I do this pre-dinner, right. And this was an innovation of the last couple of years, it\'s a fantastic psychologically for me. This is a transition from work to like family time after work. So I\'ll do like 45, 50 minutes garage gym that we built during COVID after I\'m done working before dinner. And once you get used to that like it also forces you like, I got to finish work \'cause I got to get this in before dinner. But then I\'ll do also quite a bit of walking if it\'s not a teaching day so I\'m not on campus. I do a lot of thinking on foot, walking my kids to the bus stop which isn\'t particularly close and back. So I\'ll do a lot of walking. But my serious exercise now is ...
# [{'text': 'are you a list maker like do you wake up', 'start': 2.48, 'duration': 3.08}, {'text': 'in the morning and make lists and cross', 'start': 4.12, 'duration': 3.12}, {'text': 'things off and then decide what are the', 'start': 5.56, 'duration': 3.64}, {'text': "key items on that list no I'm a Time", 'start': 7.24, 'duration': 4.72}, {'text': "blocker time blocker yeah yeah so I'm", 'start': 9.2, 'duration': 4.559}, {'text': 'not a big believer in to-do list I like', 'start': 11.96, 'duration': 3.24}, {'text': 'to Grapple with the actual available', 'start': 13.759, 'duration': 3.921}, {'text': 'time like okay I have a meeting here I', 'start': 15.2, 'duration': 3.8}, {'text': 'have to like pick my kids up from school', 'start': 17.68, 'duration': 4.0}, {'text': "here here's the actual hours of the day", 'start': 19.0, 'duration': 4.519}, {'text': 'that are free and where they fall all', 'start': 21.68, 'duration': 3.839}, {'text': 'right what do I want to do at that time', 'start': 23.519, 'duration': 3.281}, {'text': "well okay now that I see that there's a", 'start': 25.519, 'duration': 2.561}, {'text': 'lot of gaps in the middle of the day', 'start': 26.8, 'duration': 2.879}, {'text': "here they're short maybe there I'm going", 'start': 28.08, 'duration': 3.4}, {'text': 'to do lot of small non-c conly demanding', 'start': 29.679, 'duration': 3.4}, {'text': 'thing oh this first 90 minutes in the', 'start': 31.48, 'duration': 3.28}, {'text': 'morning is like the main time I have', 'start': 33.079, 'duration': 3.201}, {'text': "uninterrupted okay so this I'm going to", 'start': 34.76, 'duration': 4.24}, {'text': "work on writing so i' I've been a big", 'start': 36.28, 'duration': 3.759}, {'text': 'believer of this since I was an', 'start': 39.0, 'duration': 4.48}, {'text': 'undergrad like you give your time a job', 'start': 40.039, 'duration': 4.961}, {'text': 'as opposed to having a list which is', 'start': 43.48, 'duration': 2.84}, {'text': "somewhat orthogonal to what's actually", 'start': 45.0, 'duration': 2.8}, {'text': 'happening in your day and then just as', 'start': 46.32, 'duration': 2.52}, {'text': 'you go through your day saying what do I', 'start': 47.8, 'duration': 2.32}, {'text': 'want to try to do next which I think is', 'start': 48.84, 'duration': 2.399}, {'text': 'a lot less', 'start': 50.12, 'duration': 3.959}, {'text': "efficient I'm going to try your method", 'start': 51.239, 'duration': 4.601}, {'text': 'um I try and structure my days as much', 'start': 54.079, 'duration': 5.16}, {'text': 'as I can but it just never quite Works', 'start': 55.84, 'duration': 6.359}, {'text': 'um do work late into the night or you no', 'start': 59.239, 'duration': 6.481}, {'text': "no I'm I'm a 5:30 man okay yeah so 5:30", 'start': 62.199, 'duration': 5.481}, {'text': "p.m. that's it yeah more or less that's", 'start': 65.72, 'duration': 4.32}, {'text': 'my cut off now the the one exception is', 'start': 67.68, 'duration': 5.56}, {'text': "um if I'm writing on Deadline I'll", 'start': 70.04, 'duration': 4.439}, {'text': 'sometimes like if I need to get more', 'start': 73.24, 'duration': 3.519}, {'text': 'writing done I can do uh an evening', 'start': 74.479, 'duration': 4.041}, {'text': 'writing session which which I got used', 'start': 76.759, 'duration': 3.32}, {'text': 'to through long experience of I used to', 'start': 78.52, 'duration': 3.44}, {'text': 'write my blog post at night after like', 'start': 80.079, 'duration': 3.161}, {'text': "my kids went to bed now they're older", 'start': 81.96, 'duration': 2.6}, {'text': "and they don't go to bed as early so", 'start': 83.24, 'duration': 3.36}, {'text': "it's like the one thing I have left that", 'start': 84.56, 'duration': 3.76}, {'text': "I'll do after 5:30 is like every once in", 'start': 86.6, 'duration': 3.92}, {'text': "a while I'll do like a 90 minute evening", 'start': 88.32, 'duration': 4.4}, {'text': 'writing block um but I call this by the', 'start': ...
# [{'text': "are you a list maker like do you wake up  in the morning and make lists and cross  things off and then decide what are the  key items on that list no I'm a Time  blocker time blocker yeah yeah so I'm  not a big believer in to-do list I like  to Grapple with the actual available  time like okay I have a meeting here I  have to like pick my kids up from school  here here's the actual hours of the day  that are free and where they fall all  right what do I want to do at that time  well okay now that I see that there's a  lot of gaps in the middle of the day  here they're short maybe there I'm going  to do lot of small non-c conly demanding  thing oh this first 90 minutes in the  morning is like the main time I have  uninterrupted okay so this I'm going to  work on writing so i' I've been a big  believer of this since I was an  undergrad like you give your time a job  as opposed to having a list which is  somewhat orthogonal to what's actually  happening in your day and then just as  you go through your day saying what do I  want to try to do next which I think is  a lot less  efficient I'm going to try your method  um I try and structure my days as much  as I can but it just never quite Works  um do work late into the night or you no  no I'm I'm a 5:30 man okay yeah so 5:30  p.m. that's it yeah more or less that's  my cut off now the the one exception is  um if I'm writing on Deadline I'll  sometimes like if I need to get more  writing done I can do uh an evening  writing session which which I got used  to through long experience of I used to  write my blog post at night after like  my kids went to bed now they're older  and they don't go to bed as early so  it's like the one thing I have left that  I'll do after 5:30 is like every once in  a while I'll do like a 90 minute evening  writing block um but I call this by the  way this whole philosophy I call fix  schedule productivity and I've been  doing it since I was a grad student fix  the work hour schedule that's my  commitment I work in these hours um and  then work Downstream from that for  everything else so like this controls  like even what you decide to bring into  your life because you know I can't go  past a schedule um and it drives you to  be more Innovative and how you deal with  your time and schedule you have to be  efficient because you only have these  these hours here uh that's been you know  a signal for my my since I was in my  early 20s fix the schedule and don't  work outside of that schedule now it's  your move to figure out anything you  want to do you have to make that work  you want to become a professor figure  out how to make that work you want to  write books while you're being a  professor figure out how to make that  work you don't have the option of just  throwing hours at it and you innovate a  lot I think when you have the  constraints where do sleep and exercise  fit into your schedule uh what's your  typical to bed time wakeup time what's  your um typical exercise routine and the  reason I ask about this is because I  think nowadays we hopefully people  understand that exercise and cognitive  function are are inextricably linked  yeah and we're all going to live longer  lives and be sharper mentally by doing  exercise yeah so I mean my main like  actual working with weights I do this  predinner right and this was an  innovation the last couple of years it's  it's a fantastic psychologically for me  this is a transition from work to like  family time after work so so I'll do  like 45 50 minutes uh garage God's gym  you know that we built during Co after  I'm done working before dinner and once  you get used to that like it also forces  you to like I got to finish work because  I got to get this in before dinner but  then I'll do also quite a bit of walking  if it's not a teaching day so I'm not on  campus uh I do a lot of thinking on foot  um you know walking my kids to the bus  stop which isn't particularly close in  back so I'll do  ...
# [{'text': 'Are you a list maker?', 'start': 2.49, 'duration': 1.17}, {'text': 'Like do you wake up in\nthe morning and make lists', 'start': 3.66, 'duration': 1.5}, {'text': 'and cross things off', 'start': 5.16, 'duration': 0.93}, {'text': 'and then decide what are\nthe key items on that list?', 'start': 6.09, 'duration': 2.52}, {'text': "No, I'm a time blocker.", 'start': 8.61, 'duration': 1.29}, {'text': 'Time blocker, okay.\nYeah.', 'start': 9.9, 'duration': 1.68}, {'text': "Yeah, so I'm not a big\nbeliever in to-do list,", 'start': 11.58, 'duration': 1.86}, {'text': 'I like to grapple with\nthe actual available time.', 'start': 13.44, 'duration': 2.79}, {'text': 'Like, okay, I have a meeting here,', 'start': 16.23, 'duration': 1.44}, {'text': 'I have to like pick my\nkids up from school here.', 'start': 17.67, 'duration': 1.83}, {'text': "Here's the actual hours\nof the day that are free", 'start': 19.5, 'duration': 2.73}, {'text': 'and where they fall.', 'start': 22.23, 'duration': 1.23}, {'text': 'All right, what do I want\nto do with that time?', 'start': 23.46, 'duration': 1.98}, {'text': "Well, okay, now that I see\nthat there's a lot of gaps", 'start': 25.44, 'duration': 2.01}, {'text': "in the middle of the\nday here, they're short,", 'start': 27.45, 'duration': 1.68}, {'text': "maybe there I'm going to do a lot of small", 'start': 29.13, 'duration': 1.41}, {'text': 'non-cognitively demanding thing.', 'start': 30.54, 'duration': 1.23}, {'text': 'Oh, this first 90 minutes in the morning', 'start': 31.77, 'duration': 1.68}, {'text': 'is like the main time\nI have uninterrupted.', 'start': 33.45, 'duration': 2.01}, {'text': "Okay, so this, I'm going\nto work on writing.", 'start': 35.46, 'duration': 2.58}, {'text': "So I've been a big believer of this", 'start': 38.04, 'duration': 1.62}, {'text': 'since I was an undergrad.', 'start': 39.66, 'duration': 1.32}, {'text': 'Like you give your time a job\nas opposed to having a list,', 'start': 40.98, 'duration': 3.81}, {'text': 'which is somewhat orthogonal', 'start': 44.79, 'duration': 1.14}, {'text': "to what's actually happening in your day.", 'start': 45.93, 'duration': 1.35}, {'text': 'And then just as you go\nthrough your day saying,', 'start': 47.28, 'duration': 1.267}, {'text': '"What do I want to try to do next?"', 'start': 48.547, 'duration': 1.253}, {'text': 'Which I think is a lot less efficient.', 'start': 49.8, 'duration': 2.52}, {'text': "I'm going to try your method.", 'start': 52.32, 'duration': 1.4}, {'text': 'I try and structure my\ndays as much as I can', 'start': 54.57, 'duration': 1.8}, {'text': 'but it just never quite works.', 'start': 56.37, 'duration': 2.523}, {'text': 'Do you work late into\nthe night or you, no?', 'start': 59.76, 'duration': 2.4}, {'text': "No, I'm a 5:30 man.", 'start': 62.16, 'duration': 2.07}, {'text': 'Okay.\nYeah.', 'start': 64.23, 'duration': 0.833}, {'text': "So 5:30 p.m., that's it?", 'start': 65.063, 'duration': 1.837}, {'text': "Yeah, more or less, that's my cutoff.", 'start': 66.9, 'duration': 1.23}, {'text': "Now one exception is if\nI'm writing on deadline,", 'start': 68.13, 'duration': 4.5}, {'text': "I'll sometimes, like if I\nneed to get more writing done,", 'start': 72.63, 'duration': 2.64}, {'text': 'I can do an evening writing session', 'start': 75.27, 'duration': 2.7}, {'text': 'which I got used to\nthrough long experience of,', 'start': 77.97, 'duration': 1.86}, {'text': 'I used to write my blog post at night', 'start': 79.83, 'duration': 1.56}, {'text': 'after like my kids went to bed.', 'start': 81.39, 'duration': 1.41}, {'text': "Now they're older and they\ndon't go to bed as early.", 'start': 82.8, 'duration': 1.77}, {'text': "So it's like the one thing I have left", 'start': 84.57, 'duration': 2.04}, {'text': "that I'll do after 5:30 is\nlike every once in a while", 'start': 86.61, 'duration': 2.07}, {'text': "I'll do like a 90-minute\nevening writing block.", 'start': 88.68, 'duration': 3.24}, {'text': ...
# [{'text': 'Are you a list maker?', 'start': 2.49, 'duration': 1.17}, {'text': 'Like do you wake up in\nthe morning and make lists', 'start': 3.66, 'duration': 1.5}, {'text': 'and cross things off', 'start': 5.16, 'duration': 0.93}, {'text': 'and then decide what are\nthe key items on that list?', 'start': 6.09, 'duration': 2.52}, {'text': "No, I'm a time blocker.", 'start': 8.61, 'duration': 1.29}, {'text': 'Time blocker, okay.\nYeah.', 'start': 9.9, 'duration': 1.68}, {'text': "Yeah, so I'm not a big\nbeliever in to-do list,", 'start': 11.58, 'duration': 1.86}, {'text': 'I like to grapple with\nthe actual available time.', 'start': 13.44, 'duration': 2.79}, {'text': 'Like, okay, I have a meeting here,', 'start': 16.23, 'duration': 1.44}, {'text': 'I have to like pick my\nkids up from school here.', 'start': 17.67, 'duration': 1.83}, {'text': "Here's the actual hours\nof the day that are free", 'start': 19.5, 'duration': 2.73}, {'text': 'and where they fall.', 'start': 22.23, 'duration': 1.23}, {'text': 'All right, what do I want\nto do with that time?', 'start': 23.46, 'duration': 1.98}, {'text': "Well, okay, now that I see\nthat there's a lot of gaps", 'start': 25.44, 'duration': 2.01}, {'text': "in the middle of the\nday here, they're short,", 'start': 27.45, 'duration': 1.68}, {'text': "maybe there I'm going to do a lot of small", 'start': 29.13, 'duration': 1.41}, {'text': 'non-cognitively demanding thing.', 'start': 30.54, 'duration': 1.23}, {'text': 'Oh, this first 90 minutes in the morning', 'start': 31.77, 'duration': 1.68}, {'text': 'is like the main time\nI have uninterrupted.', 'start': 33.45, 'duration': 2.01}, {'text': "Okay, so this, I'm going\nto work on writing.", 'start': 35.46, 'duration': 2.58}, {'text': "So I've been a big believer of this", 'start': 38.04, 'duration': 1.62}, {'text': 'since I was an undergrad.', 'start': 39.66, 'duration': 1.32}, {'text': 'Like you give your time a job\nas opposed to having a list,', 'start': 40.98, 'duration': 3.81}, {'text': 'which is somewhat orthogonal', 'start': 44.79, 'duration': 1.14}, {'text': "to what's actually happening in your day.", 'start': 45.93, 'duration': 1.35}, {'text': 'And then just as you go\nthrough your day saying,', 'start': 47.28, 'duration': 1.267}, {'text': '"What do I want to try to do next?"', 'start': 48.547, 'duration': 1.253}, {'text': 'Which I think is a lot less efficient.', 'start': 49.8, 'duration': 2.52}, {'text': "I'm going to try your method.", 'start': 52.32, 'duration': 1.4}, {'text': 'I try and structure my\ndays as much as I can', 'start': 54.57, 'duration': 1.8}, {'text': 'but it just never quite works.', 'start': 56.37, 'duration': 2.523}, {'text': 'Do you work late into\nthe night or you, no?', 'start': 59.76, 'duration': 2.4}, {'text': "No, I'm a 5:30 man.", 'start': 62.16, 'duration': 2.07}, {'text': 'Okay.\nYeah.', 'start': 64.23, 'duration': 0.833}, {'text': "So 5:30 p.m., that's it?", 'start': 65.063, 'duration': 1.837}, {'text': "Yeah, more or less, that's my cutoff.", 'start': 66.9, 'duration': 1.23}, {'text': "Now one exception is if\nI'm writing on deadline,", 'start': 68.13, 'duration': 4.5}, {'text': "I'll sometimes, like if I\nneed to get more writing done,", 'start': 72.63, 'duration': 2.64}, {'text': 'I can do an evening writing session', 'start': 75.27, 'duration': 2.7}, {'text': 'which I got used to\nthrough long experience of,', 'start': 77.97, 'duration': 1.86}, {'text': 'I used to write my blog post at night', 'start': 79.83, 'duration': 1.56}, {'text': 'after like my kids went to bed.', 'start': 81.39, 'duration': 1.41}, {'text': "Now they're older and they\ndon't go to bed as early.", 'start': 82.8, 'duration': 1.77}, {'text': "So it's like the one thing I have left", 'start': 84.57, 'duration': 2.04}, {'text': "that I'll do after 5:30 is\nlike every once in a while", 'start': 86.61, 'duration': 2.07}, {'text': "I'll do like a 90-minute\nevening writing block.", 'start': 88.68, 'duration': 3.24}, {'text': ...
# [{'text': 'are you a list maker like do you wake up', 'start': 2.48, 'duration': 3.08}, {'text': 'in the morning and make lists and cross', 'start': 4.12, 'duration': 3.12}, {'text': 'things off and then decide what are the', 'start': 5.56, 'duration': 3.64}, {'text': "key items on that list no I'm a Time", 'start': 7.24, 'duration': 4.72}, {'text': "blocker time blocker yeah yeah so I'm", 'start': 9.2, 'duration': 4.559}, {'text': 'not a big believer in to-do list I like', 'start': 11.96, 'duration': 3.24}, {'text': 'to Grapple with the actual available', 'start': 13.759, 'duration': 3.921}, {'text': 'time like okay I have a meeting here I', 'start': 15.2, 'duration': 3.8}, {'text': 'have to like pick my kids up from school', 'start': 17.68, 'duration': 4.0}, {'text': "here here's the actual hours of the day", 'start': 19.0, 'duration': 4.519}, {'text': 'that are free and where they fall all', 'start': 21.68, 'duration': 3.839}, {'text': 'right what do I want to do at that time', 'start': 23.519, 'duration': 3.281}, {'text': "well okay now that I see that there's a", 'start': 25.519, 'duration': 2.561}, {'text': 'lot of gaps in the middle of the day', 'start': 26.8, 'duration': 2.879}, {'text': "here they're short maybe there I'm going", 'start': 28.08, 'duration': 3.4}, {'text': 'to do lot of small non-c conly demanding', 'start': 29.679, 'duration': 3.4}, {'text': 'thing oh this first 90 minutes in the', 'start': 31.48, 'duration': 3.28}, {'text': 'morning is like the main time I have', 'start': 33.079, 'duration': 3.201}, {'text': "uninterrupted okay so this I'm going to", 'start': 34.76, 'duration': 4.24}, {'text': "work on writing so i' I've been a big", 'start': 36.28, 'duration': 3.759}, {'text': 'believer of this since I was an', 'start': 39.0, 'duration': 4.48}, {'text': 'undergrad like you give your time a job', 'start': 40.039, 'duration': 4.961}, {'text': 'as opposed to having a list which is', 'start': 43.48, 'duration': 2.84}, {'text': "somewhat orthogonal to what's actually", 'start': 45.0, 'duration': 2.8}, {'text': 'happening in your day and then just as', 'start': 46.32, 'duration': 2.52}, {'text': 'you go through your day saying what do I', 'start': 47.8, 'duration': 2.32}, {'text': 'want to try to do next which I think is', 'start': 48.84, 'duration': 2.399}, {'text': 'a lot less', 'start': 50.12, 'duration': 3.959}, {'text': "efficient I'm going to try your method", 'start': 51.239, 'duration': 4.601}, {'text': 'um I try and structure my days as much', 'start': 54.079, 'duration': 5.16}, {'text': 'as I can but it just never quite Works', 'start': 55.84, 'duration': 6.359}, {'text': 'um do work late into the night or you no', 'start': 59.239, 'duration': 6.481}, {'text': "no I'm I'm a 5:30 man okay yeah so 5:30", 'start': 62.199, 'duration': 5.481}, {'text': "p.m. that's it yeah more or less that's", 'start': 65.72, 'duration': 4.32}, {'text': 'my cut off now the the one exception is', 'start': 67.68, 'duration': 5.56}, {'text': "um if I'm writing on Deadline I'll", 'start': 70.04, 'duration': 4.439}, {'text': 'sometimes like if I need to get more', 'start': 73.24, 'duration': 3.519}, {'text': 'writing done I can do uh an evening', 'start': 74.479, 'duration': 4.041}, {'text': 'writing session which which I got used', 'start': 76.759, 'duration': 3.32}, {'text': 'to through long experience of I used to', 'start': 78.52, 'duration': 3.44}, {'text': 'write my blog post at night after like', 'start': 80.079, 'duration': 3.161}, {'text': "my kids went to bed now they're older", 'start': 81.96, 'duration': 2.6}, {'text': "and they don't go to bed as early so", 'start': 83.24, 'duration': 3.36}, {'text': "it's like the one thing I have left that", 'start': 84.56, 'duration': 3.76}, {'text': "I'll do after 5:30 is like every once in", 'start': 86.6, 'duration': 3.92}, {'text': "a while I'll do like a 90 minute evening", 'start': 88.32, 'duration': 4.4}, {'text': 'writing block um but I call this by the', 'start': ...

# %%
transcript_text = ""
for transcript in transcript_list:
    transcript_text += transcript['text'] + " "

# %%
def extract_transcript(url):
  """Extracts the transcript of a YouTube video.

  Args:
    url: The URL of the YouTube video.

  Returns:
    A list of dictionaries, each containing the text, start time, and duration of a segment of the transcript.
  """

  video_id = url.split('/')[-1].split('=')[-1]

  # Retrieve the available transcripts
  transcript_list = YouTubeTranscriptApi.list_transcripts(video_id)

  # Find the first transcript in English
  transcript = transcript_list.find_transcript(['en'])

  if transcript is None:
    raise ValueError('No English transcript found for video: {}'.format(video_id))

  # Fetch the actual transcript data
  return transcript.fetch()

# %%
extract_transcript("https://www.youtube.com/watch?v=R5i8alK5hPo")
# Out:
# [{'text': "so over the last five years I've read",
#   'start': 0.0,
#   'duration': 4.5},
#  {'text': 'pretty much every time management book',
#   'start': 2.639,
#   'duration': 3.901},
#  {'text': 'out there and there are four habits that',
#   'start': 4.5,
#   'duration': 4.86},
#  {'text': 'I genuinely use every single day to make',
#   'start': 6.54,
#   'duration': 4.8},
#  {'text': 'my time management more efficient which',
#   'start': 9.36,
#   'duration': 4.319},
#  {'text': 'I think allows me to be a very busy',
#   'start': 11.34,
#   'duration': 4.14},
#  {'text': 'corporate lawyer while also running a',
#   'start': 13.679,
#   'duration': 3.661},
#  {'text': 'YouTube channel and a business staying',
#   'start': 15.48,
#   'duration': 3.78},
#  {'text': 'fit and keeping a healthy relationship',
#   'start': 17.34,
#   'duration': 4.8},
#  {'text': 'with Beth I also then find time to read',
#   'start': 19.26,
#   'duration': 6.359},
#  {'text': 'watch TV and see some friends even so',
#   'start': 22.14,
#   'duration': 5.639},
#  {'text': "let's run through those four habits in",
#   'start': 25.619,
#   'duration': 4.561},
#  {'text': 'this video habit number one is to treat',
#   'start': 27.779,
#   'duration': 4.561},
#  {'text': "work sessions like you're going to the",
#   'start': 30.18,
#   'duration': 4.68},
#  {'text': "cinema so if you're not one of the",
#   'start': 32.34,
#   'duration': 4.32},
#  {'text': 'losers unless you have genuine bladder',
#   'start': 34.86,
#   'duration': 4.379},
#  {'text': 'issues who needs to go to the Loo during',
#   'start': 36.66,
#   'duration': 4.919},
#  {'text': 'a film you will have prepared yourself',
#   'start': 39.239,
#   'duration': 5.64},
#  {'text': 'to be sat in a seat watching the film',
#   'start': 41.579,
#   'duration': 5.16},
#  {'text': 'immersed in that experience for maybe',
#   'start': 44.879,
#   'duration': 4.381},
#  {'text': 'two and a half hours without moving and',
#   'start': 46.739,
#   'duration': 4.861},
#  {'text': 'I think we should treat work sessions in',
#   'start': 49.26,
#   'duration': 4.26},
#  {'text': 'order to enable us to get into a state',
#   'start': 51.6,
#   'duration': 5.279},
#  {'text': 'of flow of genuine immersion in our work',
#   'start': 53.52,
#   'duration': 5.699},
#  {'text': 'in exactly the same way I picked up this',
#   'start': 56.879,
#   'duration': 3.961},
#  {'text': 'idea a few years ago go from Gary',
#   'start': 59.219,
#   'duration': 3.961},
#  {'text': "Keller's book The one thing and it has",
#   'start': 60.84,
#   'duration': 4.2},
#  {'text': 'honestly been a complete game changer',
#   'start': 63.18,
#   'duration': 3.72},
#  {'text': 'for me I think just going into a work',
#   'start': 65.04,
#   'duration': 3.24},
#  {'text': 'session thinking I actually need to',
#   'start': 66.9,
#   'duration': 3.96},
#  {'text': 'prepare to sit here for an hour hour and',
#   'start': 68.28,
#   'duration': 4.68},
#  {'text': 'a half and be really focused has really',
#   'start': 70.86,
#   'duration': 4.32},
#  {'text': 'changed how I think about work sessions',
#   'start': 72.96,
#   'duration': 4.08},
#  {'text': 'it means that before I sit down to work',
#   'start': 75.18,
#   'duration': 3.9},
#  {'text': 'in the office or at home I make sure I',
#   'start': 77.04,
#   'duration': 4.079},
#  {'text': 'bend to the toilet stretched my legs got',
#   'start': 79.08,
#   'duration': 4.56},
#  {'text': 'myself a drink and a healthier than I',
#   'start': 81.119,
#   'duration': 4.261},
#  {'text': 'probably would at the cinema snack and',
#   'start': 83.64,
#   'duration': 3.839},
#  {'text': 'then also made sure that my phone is on',
#   'start': 85.38,
#   'duration': 3.84},
#  {'text': 'silent not gonna disturb me make sure',
#   'start': 87.479,
#   'duration': 3.601},
#  {'text': 'that notifications or do not disturb is',
#   'start': 89.22,
#   'duration': 3.719},
#  {'text': 'on allowing me to really immerse myself',
#   'start': 91.08,
#   'duration': 3.899},
#  {'text': "in the work that I'm about to do and",
#   'start': 92.939,
#   'duration': 3.661},
#  {'text': "just like when you're at the cinema if",
#   'start': 94.979,
#   'duration': 3.061},
#  {'text': "you're like me and you find it hugely",
#   'start': 96.6,
#   'duration': 2.82},
#  {'text': 'distracting and annoying when people',
#   'start': 98.04,
#   'duration': 2.7},
#  {'text': 'like rustling around in their popcorn',
#   'start': 99.42,
#   'duration': 3.3},
#  {'text': 'and generally making noise around you',
#   'start': 100.74,
#   'duration': 3.839},
#  {'text': 'taking you out of that like state of',
#   'start': 102.72,
#   'duration': 3.78},
#  {'text': 'flow of watching the film I really',
#   'start': 104.579,
#   'duration': 4.741},
#  {'text': 'strongly recommend that you use either a',
#   'start': 106.5,
#   'duration': 5.28},
#  {'text': "playlist or an app like endle today's",
#   'start': 109.32,
#   'duration': 4.619},
#  {'text': 'sponsor more on them later to really',
#   'start': 111.78,
#   'duration': 4.619},
#  {'text': 'block out any distracting noise this is',
#   'start': 113.939,
#   'duration': 4.081},
#  {'text': "so important for me that for when I'm in",
#   'start': 116.399,
#   'duration': 3.18},
#  {'text': 'the office I have my airpods Pro with',
#   'start': 118.02,
#   'duration': 3.54},
#  {'text': "the noise canceling function on they're",
#   'start': 119.579,
#   'duration': 4.201},
#  {'text': 'much more discreet than my bigger Bose',
#   'start': 121.56,
#   'duration': 3.72},
#  {'text': 'noise canceling headphones that I wear',
#   'start': 123.78,
#   'duration': 3.18},
#  {'text': "when I'm at home all of that then puts",
#   'start': 125.28,
#   'duration': 3.36},
#  {'text': 'me in a state of mind where I am ready',
#   'start': 126.96,
#   'duration': 3.659},
#  {'text': 'to get into a state of flow and',
#   'start': 128.64,
#   'duration': 3.66},
#  {'text': "immersion in the work that I'm going to",
#   'start': 130.619,
#   'duration': 3.301},
#  {'text': 'do the second habit is the batch task',
#   'start': 132.3,
#   'duration': 3.299},
#  {'text': 'before you start so batching is a very',
#   'start': 133.92,
#   'duration': 3.899},
#  {'text': 'simple idea where rather than switching',
#   'start': 135.599,
#   'duration': 3.961},
#  {'text': "between I'm going to water this plant",
#   'start': 137.819,
#   'duration': 4.081},
#  {'text': "here and then I'm gonna do a bit of",
#   'start': 139.56,
#   'duration': 4.319},
#  {'text': "reading and then I'm gonna do some work",
#   'start': 141.9,
#   'duration': 3.3},
#  {'text': "and then I'm gonna clean the floor",
#   'start': 143.879,
#   'duration': 3.961},
#  {'text': 'upstairs you try to batch similar tasks',
#   'start': 145.2,
#   'duration': 4.56},
#  {'text': 'so watering all of the plants at the',
#   'start': 147.84,
#   'duration': 3.6},
#  {'text': 'same time all at once which just',
#   'start': 149.76,
#   'duration': 3.36},
#  {'text': 'generally makes life way more efficient',
#   'start': 151.44,
#   'duration': 3.12},
#  {'text': 'I think the question here is really just',
#   'start': 153.12,
#   'duration': 3.6},
#  {'text': 'like how do I Implement batching day to',
#   'start': 154.56,
#   'duration': 3.539},
#  {'text': 'day I think there are really two ways',
#   'start': 156.72,
#   'duration': 3.48},
#  {'text': 'that I Implement batching the first is',
#   'start': 158.099,
#   'duration': 4.021},
#  {'text': 'batching by project what I mean by that',
#   'start': 160.2,
#   'duration': 3.6},
#  {'text': "is that when I'm at work and I'm working",
#   'start': 162.12,
#   'duration': 3.72},
#  {'text': "on let's say something for my client",
#   'start': 163.8,
#   'duration': 4.98},
#  {'text': 'James when I have all of the emails and',
#   'start': 165.84,
#   'duration': 5.399},
#  {'text': "documents open from James it's way more",
#   'start': 168.78,
#   'duration': 4.319},
#  {'text': 'efficient for me to do all of the work',
#   'start': 171.239,
#   'duration': 3.78},
#  {'text': 'for James while I have everything there',
#   'start': 173.099,
#   'duration': 4.081},
#  {'text': 'and open than it is to do something for',
#   'start': 175.019,
#   'duration': 3.961},
#  {'text': 'James and then think oh actually I',
#   'start': 177.18,
#   'duration': 3.66},
#  {'text': 'really need to do that thing for Sandra',
#   'start': 178.98,
#   'duration': 3.36},
#  {'text': "so I'll just switch over and close",
#   'start': 180.84,
#   'duration': 2.88},
#  {'text': 'everything and then need to open',
#   'start': 182.34,
#   'duration': 2.88},
#  {'text': 'everything for Sandra and then open',
#   'start': 183.72,
#   'duration': 3.36},
#  {'text': 'everything again for James later when I',
#   'start': 185.22,
#   'duration': 3.72},
#  {'text': 'go back to James batching by project',
#   'start': 187.08,
#   'duration': 3.659},
#  {'text': 'effectively means do everything for',
#   'start': 188.94,
#   'duration': 3.54},
#  {'text': 'James and then everything for Sandra it',
#   'start': 190.739,
#   'duration': 2.761},
#  {'text': 'sounds pretty obvious but I think',
#   'start': 192.48,
#   'duration': 3.0},
#  {'text': 'actually being really conscious of when',
#   'start': 193.5,
#   'duration': 3.9},
#  {'text': 'you are switching between projects way',
#   'start': 195.48,
#   'duration': 3.899},
#  {'text': 'too frequently is a hugely healthy',
#   'start': 197.4,
#   'duration': 3.6},
#  {'text': 'mindset to adopt it allows you to be',
#   'start': 199.379,
#   'duration': 2.761},
#  {'text': "much more efficient in how you're",
#   'start': 201.0,
#   'duration': 3.3},
#  {'text': 'working both practically in terms of not',
#   'start': 202.14,
#   'duration': 3.42},
#  {'text': 'having to open and close different',
#   'start': 204.3,
#   'duration': 3.84},
#  {'text': 'things for different projects and also',
#   'start': 205.56,
#   'duration': 4.38},
#  {'text': 'in terms of how your mind is operating',
#   'start': 208.14,
#   'duration': 4.019},
#  {'text': 'it is in the mindset of working for',
#   'start': 209.94,
#   'duration': 4.2},
#  {'text': 'James do all of the work for James while',
#   'start': 212.159,
#   'duration': 4.08},
#  {'text': 'your mind is focused and in that frame',
#   'start': 214.14,
#   'duration': 3.599},
#  {'text': 'of mind rather than switching between',
#   'start': 216.239,
#   'duration': 3.481},
#  {'text': 'different projects a top tip for me is',
#   'start': 217.739,
#   'duration': 3.42},
#  {'text': "when I'm at work and I'm working on say",
#   'start': 219.72,
#   'duration': 2.76},
#  {'text': 'three different projects at once I',
#   'start': 221.159,
#   'duration': 3.241},
#  {'text': 'actually have a different desktop for',
#   'start': 222.48,
#   'duration': 3.42},
#  {'text': 'each of those different projects so I',
#   'start': 224.4,
#   'duration': 3.72},
#  {'text': 'actually have to move between desktops',
#   'start': 225.9,
#   'duration': 4.08},
#  {'text': 'which obviously allows me to keep all of',
#   'start': 228.12,
#   'duration': 3.24},
#  {'text': 'the stuff relevant to a single project',
#   'start': 229.98,
#   'duration': 4.38},
#  {'text': 'open in One desktop all at once and also',
#   'start': 231.36,
#   'duration': 5.159},
#  {'text': 'creates resistance for me in terms of',
#   'start': 234.36,
#   'duration': 3.78},
#  {'text': 'flicking between the different tasks',
#   'start': 236.519,
#   'duration': 3.241},
#  {'text': 'across different projects in the second',
#   'start': 238.14,
#   'duration': 3.179},
#  {'text': 'kind of batching is just batching by',
#   'start': 239.76,
#   'duration': 4.259},
#  {'text': 'task so unless I get an insanely urgent',
#   'start': 241.319,
#   'duration': 5.461},
#  {'text': 'email I try not to reply to emails more',
#   'start': 244.019,
#   'duration': 5.401},
#  {'text': "than once every hour or two so I'll let",
#   'start': 246.78,
#   'duration': 4.5},
#  {'text': 'my emails build up and then do the task',
#   'start': 249.42,
#   'duration': 4.08},
#  {'text': 'of writing and replying to emails all at',
#   'start': 251.28,
#   'duration': 4.739},
#  {'text': 'once I also batch tasks outside of work',
#   'start': 253.5,
#   'duration': 4.56},
#  {'text': "so for example when I'm cooking a meal",
#   'start': 256.019,
#   'duration': 4.081},
#  {'text': "I'll make sure I cook two or three meals",
#   'start': 258.06,
#   'duration': 4.139},
#  {'text': "worth of that recipe because it doesn't",
#   'start': 260.1,
#   'duration': 4.319},
#  {'text': 'take massively more time to cook two or',
#   'start': 262.199,
#   'duration': 4.321},
#  {'text': 'three times the amount but obviously if',
#   'start': 264.419,
#   'duration': 3.78},
#  {'text': 'I cook a new meal every single night',
#   'start': 266.52,
#   'duration': 3.66},
#  {'text': 'that takes way longer and I also batch',
#   'start': 268.199,
#   'duration': 4.44},
#  {'text': "chores so if I'm cleaning I'll clean the",
#   'start': 270.18,
#   'duration': 4.56},
#  {'text': 'entire house for three hours rather than',
#   'start': 272.639,
#   'duration': 4.021},
#  {'text': 'doing bits and Bobs here and there so',
#   'start': 274.74,
#   'duration': 3.72},
#  {'text': 'yeah for me batching is really all about',
#   'start': 276.66,
#   'duration': 3.479},
#  {'text': 'just having a consciousness of doing',
#   'start': 278.46,
#   'duration': 4.08},
#  {'text': 'more of this type of task or this type',
#   'start': 280.139,
#   'duration': 5.28},
#  {'text': 'of project right now to avoid having to',
#   'start': 282.54,
#   'duration': 5.4},
#  {'text': 'switch between things losing focus and',
#   'start': 285.419,
#   'duration': 4.441},
#  {'text': 'overall just spending more time than I',
#   'start': 287.94,
#   'duration': 4.14},
#  {'text': 'should be on those tasks so before we',
#   'start': 289.86,
#   'duration': 3.66},
#  {'text': 'move on to the final two habits I really',
#   'start': 292.08,
#   'duration': 2.52},
#  {'text': "quickly want to tell you about today's",
#   'start': 293.52,
#   'duration': 3.0},
#  {'text': 'sponsor endle which has pretty quickly',
#   'start': 294.6,
#   'duration': 5.099},
#  {'text': 'become probably my most used app it',
#   'start': 296.52,
#   'duration': 5.28},
#  {'text': 'create personalized real-time',
#   'start': 299.699,
#   'duration': 4.921},
#  {'text': 'soundscapes that help you focus relax or',
#   'start': 301.8,
#   'duration': 3.72},
#  {'text': 'sleep', 'start': 304.62, 'duration': 3.299},
#  {'text': 'so handle is without a doubt the single',
#   'start': 305.52,
#   'duration': 4.26},
#  {'text': "best app I've ever had to get me in the",
#   'start': 307.919,
#   'duration': 3.72},
#  {'text': "zone whenever I'm finding it hard to",
#   'start': 309.78,
#   'duration': 3.78},
#  {'text': 'concentrate on work especially if',
#   'start': 311.639,
#   'duration': 3.301},
#  {'text': "there's background noise where I'm",
#   'start': 313.56,
#   'duration': 2.94},
#  {'text': "working which I'm particularly bad at",
#   'start': 314.94,
#   'duration': 3.96},
#  {'text': 'blocking out Endo is informed by science',
#   'start': 316.5,
#   'duration': 4.32},
#  {'text': 'created with science and backed by',
#   'start': 318.9,
#   'duration': 4.32},
#  {'text': "science it's an environment-based app",
#   'start': 320.82,
#   'duration': 4.08},
#  {'text': 'that takes everything we know about',
#   'start': 323.22,
#   'duration': 4.56},
#  {'text': 'sound to create real-time personalized',
#   'start': 324.9,
#   'duration': 5.16},
#  {'text': 'soundscapes that help with Focus as well',
#   'start': 327.78,
#   'duration': 5.16},
#  {'text': 'as relaxation and sleep I genuinely find',
#   'start': 330.06,
#   'duration': 5.04},
#  {'text': "end-all complements my body's natural",
#   'start': 332.94,
#   'duration': 5.34},
#  {'text': 'circadian rhythms using its AI powered',
#   'start': 335.1,
#   'duration': 5.22},
#  {'text': "technology to help me relax when I'm",
#   'start': 338.28,
#   'duration': 4.139},
#  {'text': "stressed I always listen to andel's",
#   'start': 340.32,
#   'duration': 3.96},
#  {'text': 'relax mode on my way home from work when',
#   'start': 342.419,
#   'duration': 4.801},
#  {'text': "I've had a tough day or to reliably get",
#   'start': 344.28,
#   'duration': 5.46},
#  {'text': 'me in the mood to sleep even when I feel',
#   'start': 347.22,
#   'duration': 5.28},
#  {'text': 'a bit Restless I absolutely love their',
#   'start': 349.74,
#   'duration': 5.34},
#  {'text': 'gentle alarm that slowly wakes me up in',
#   'start': 352.5,
#   'duration': 5.759},
#  {'text': 'the morning rather than that', 'start': 355.08, 'duration': 6.42},
#  {'text': "we all know and hate and I'm also a huge",
#   'start': 358.259,
#   'duration': 5.28},
#  {'text': "fan of endel's scenario mode which",
#   'start': 361.5,
#   'duration': 3.9},
#  {'text': "allows me to tell the app okay I'm gonna",
#   'start': 363.539,
#   'duration': 4.801},
#  {'text': "do deep work now I'm gonna do it for 16",
#   'start': 365.4,
#   'duration': 5.04},
#  {'text': 'minutes and then I get a soundscape to',
#   'start': 368.34,
#   'duration': 4.02},
#  {'text': 'help me get in the zone for that entire',
#   'start': 370.44,
#   'duration': 4.44},
#  {'text': 'work session so if you want to start',
#   'start': 372.36,
#   'duration': 5.1},
#  {'text': "using endo's amazing soundscapes that",
#   'start': 374.88,
#   'duration': 4.62},
#  {'text': 'keep me focused for hours pretty much',
#   'start': 377.46,
#   'duration': 4.56},
#  {'text': 'every single day follow the link in the',
#   'start': 379.5,
#   'duration': 4.5},
#  {'text': 'description and the first 100 people to',
#   'start': 382.02,
#   'duration': 4.32},
#  {'text': 'download endl will get a free week of',
#   'start': 384.0,
#   'duration': 4.02},
#  {'text': 'audio experiences', 'start': 386.34, 'duration': 4.38},
#  {'text': 'alrighty third habit is to try to avoid',
#   'start': 388.02,
#   'duration': 5.82},
#  {'text': 'work before doing the work and this is',
#   'start': 390.72,
#   'duration': 5.039},
#  {'text': "inspired by Grace Beverly's book working",
#   'start': 393.84,
#   'duration': 4.079},
#  {'text': 'hard hardly working so there are two',
#   'start': 395.759,
#   'duration': 4.261},
#  {'text': 'ways that I try and I think anyone can',
#   'start': 397.919,
#   'duration': 5.34},
#  {'text': 'try to avoid doing work myself in order',
#   'start': 400.02,
#   'duration': 5.04},
#  {'text': 'to have more time for other stuff the',
#   'start': 403.259,
#   'duration': 3.541},
#  {'text': 'first is to delegate I think in a work',
#   'start': 405.06,
#   'duration': 3.72},
#  {'text': "context it's so easy to be given a task",
#   'start': 406.8,
#   'duration': 4.019},
#  {'text': 'to instantly jump into doing it and five',
#   'start': 408.78,
#   'duration': 4.62},
#  {'text': "hours later you've finished so for me",
#   'start': 410.819,
#   'duration': 3.961},
#  {'text': 'the Habit is really just them five',
#   'start': 413.4,
#   'duration': 3.96},
#  {'text': 'minutes thinking before I jump into this',
#   'start': 414.78,
#   'duration': 4.919},
#  {'text': 'task are there other people who can more',
#   'start': 417.36,
#   'duration': 4.02},
#  {'text': 'effectively do this than me are there',
#   'start': 419.699,
#   'duration': 2.94},
#  {'text': 'people who could help people with more',
#   'start': 421.38,
#   'duration': 3.539},
#  {'text': 'expertise in this area than me I really',
#   'start': 422.639,
#   'duration': 4.141},
#  {'text': 'do genuinely find it so tough to',
#   'start': 424.919,
#   'duration': 3.241},
#  {'text': "delegate because I'm quite protective of",
#   'start': 426.78,
#   'duration': 2.699},
#  {'text': 'my work I really want the work to be',
#   'start': 428.16,
#   'duration': 3.18},
#  {'text': 'high quality but I think getting into a',
#   'start': 429.479,
#   'duration': 3.84},
#  {'text': 'habit of considering options to',
#   'start': 431.34,
#   'duration': 4.62},
#  {'text': 'Outsource is absolutely critical if you',
#   'start': 433.319,
#   'duration': 4.261},
#  {'text': 'want to make the most of your time and',
#   'start': 435.96,
#   'duration': 3.179},
#  {'text': 'the second is to use Tech or other',
#   'start': 437.58,
#   'duration': 3.0},
#  {'text': 'resources and I think in that five',
#   'start': 439.139,
#   'duration': 2.521},
#  {'text': "minute period where you're just thinking",
#   'start': 440.58,
#   'duration': 3.179},
#  {'text': "can I do this more effectively it's",
#   'start': 441.66,
#   'duration': 4.379},
#  {'text': 'worth thinking are there Tech tools that',
#   'start': 443.759,
#   'duration': 3.72},
#  {'text': 'I could use are there other people',
#   'start': 446.039,
#   'duration': 3.0},
#  {'text': "who've probably really done this task",
#   'start': 447.479,
#   'duration': 3.181},
#  {'text': 'before who might be able to say actually',
#   'start': 449.039,
#   'duration': 3.78},
#  {'text': "there's this really useful Excel formula",
#   'start': 450.66,
#   'duration': 4.02},
#  {'text': 'that will solve all of your problems so',
#   'start': 452.819,
#   'duration': 3.061},
#  {'text': 'in a couple of minutes digging around',
#   'start': 454.68,
#   'duration': 2.94},
#  {'text': 'for tools asking other people who have',
#   'start': 455.88,
#   'duration': 3.96},
#  {'text': 'probably done that task before for how',
#   'start': 457.62,
#   'duration': 3.54},
#  {'text': 'they did it and what lessons they',
#   'start': 459.84,
#   'duration': 3.359},
#  {'text': 'learned before diving in and fourth and',
#   'start': 461.16,
#   'duration': 4.86},
#  {'text': 'final habit is to multitask and if you',
#   'start': 463.199,
#   'duration': 4.62},
#  {'text': 'scour YouTube you will find a ton of',
#   'start': 466.02,
#   'duration': 3.959},
#  {'text': 'advice saying that multitasking is the',
#   'start': 467.819,
#   'duration': 4.32},
#  {'text': 'least productive most awful thing you',
#   'start': 469.979,
#   'duration': 4.5},
#  {'text': 'can possibly do and I generally do agree',
#   'start': 472.139,
#   'duration': 4.381},
#  {'text': 'I think batching and focusing on doing',
#   'start': 474.479,
#   'duration': 3.601},
#  {'text': 'one thing at a time is absolutely',
#   'start': 476.52,
#   'duration': 4.019},
#  {'text': 'essential to productivity but I have one',
#   'start': 478.08,
#   'duration': 4.44},
#  {'text': 'specific rule that allows me to',
#   'start': 480.539,
#   'duration': 4.681},
#  {'text': 'multitask and save so much time every',
#   'start': 482.52,
#   'duration': 5.82},
#  {'text': 'week and that is to use my brain and my',
#   'start': 485.22,
#   'duration': 5.52},
#  {'text': "body at the same time so I've been using",
#   'start': 488.34,
#   'duration': 3.96},
#  {'text': 'my body doing something physical like',
#   'start': 490.74,
#   'duration': 3.899},
#  {'text': 'walking to work or exercise or chores',
#   'start': 492.3,
#   'duration': 4.98},
#  {'text': 'around the house I am able to use my',
#   'start': 494.639,
#   'duration': 4.5},
#  {'text': 'brain while doing those physical things',
#   'start': 497.28,
#   'duration': 3.599},
#  {'text': 'so that might mean listening to an audio',
#   'start': 499.139,
#   'duration': 4.021},
#  {'text': 'book or a podcast or just thinking about',
#   'start': 500.879,
#   'duration': 4.32},
#  {'text': "my business and similarly if I'm using",
#   'start': 503.16,
#   'duration': 4.14},
#  {'text': 'my brain to work I can then use my body',
#   'start': 505.199,
#   'duration': 3.961},
#  {'text': 'to do something physical like standing',
#   'start': 507.3,
#   'duration': 3.54},
#  {'text': 'at my desk I even have a friend who has',
#   'start': 509.16,
#   'duration': 3.36},
#  {'text': 'a treadmill that she walks on while',
#   'start': 510.84,
#   'duration': 3.3},
#  {'text': "she's on calls I also have this spiky",
#   'start': 512.52,
#   'duration': 3.24},
#  {'text': 'ball thing that I roll my foot on while',
#   'start': 514.14,
#   'duration': 3.0},
#  {'text': "I'm at my desk just to improve", 'start': 515.76, 'duration': 3.48},
#  {'text': 'flexibility in my foot and lower leg and',
#   'start': 517.14,
#   'duration': 3.54},
#  {'text': "if I'm on a call where I'm not really",
#   'start': 519.24,
#   'duration': 3.239},
#  {'text': 'talking much and not on camera I might',
#   'start': 520.68,
#   'duration': 3.659},
#  {'text': 'stretch for five minutes anything you',
#   'start': 522.479,
#   'duration': 3.841},
#  {'text': 'can do really to get some kind of',
#   'start': 524.339,
#   'duration': 3.421},
#  {'text': "movement in your body while you're",
#   'start': 526.32,
#   'duration': 2.88},
#  {'text': 'working I think is a really healthy',
#   'start': 527.76,
#   'duration': 3.0},
#  {'text': "Habit to get into so yeah if you're",
#   'start': 529.2,
#   'duration': 3.48},
#  {'text': 'using your brain or your body think how',
#   'start': 530.76,
#   'duration': 3.9},
#  {'text': 'can I use the other one at the same time',
#   'start': 532.68,
#   'duration': 3.96},
#  {'text': 'so yeah those are my four kind of small',
#   'start': 534.66,
#   'duration': 4.98},
#  {'text': 'simple but highly effective habits that',
#   'start': 536.64,
#   'duration': 5.34},
#  {'text': 'honestly I reckon save me at least 20',
#   'start': 539.64,
#   'duration': 4.259},
#  {'text': 'hours every week let me know if you have',
#   'start': 541.98,
#   'duration': 3.72},
#  {'text': 'any habits you think I should adopt that',
#   'start': 543.899,
#   'duration': 3.721},
#  {'text': 'could save me even more time and I look',
#   'start': 545.7,
#   'duration': 5.78},
#  {'text': 'forward to speaking again very soon',
#   'start': 547.62,
#   'duration': 3.86}]

# %%
def youtube_transcript_loader(url):
    from youtube_transcript_api import YouTubeTranscriptApi
    try:
        video_id = url.split('/')[-1].split('=')[-1]
        transcript_list = YouTubeTranscriptApi.list_transcripts(video_id)
        transcript = transcript_list.find_transcript(['en'])

        if transcript is None:
            raise ValueError('No English transcript found for video: {}'.format(video_id))

        list_t =  transcript.fetch()
    
        transcript_text = ""
        for transcript in list_t:
            transcript_text += transcript['text'] + " "
        return transcript_text
    except Exception as e:
        return f"Error: {e}"

# %%
youtube_transcript_loader("https://www.youtube.com/watch?v=ovS83zHyhMs")
# Out:
# "hello everyone welcome to AI anytime channel in this video we are going to see how we can use a no code platform called def aai with ol Lama earlier I have a video where I've shown how you can use Dy AI you know and geni Innovation engine a completely you know a low code no code platform where you can build jna applications faster and in that video I have shown with close Source models where you need an API key now for example if you want to use models like gp40 om mini you know Cloud models Gemini models Gro models so on and so forth so you need an API key over there to use that but you know most of the time you would not use these apis you want to use something which is open source where you can self host it you know where you can control everything you know mainly from a data confidentiality standpoint right because your data is confidential and you would not like to send that data to a third party company for example here the llm providers so how we can use o Lama a tool that basically helps you inference or run large language models locally in your machine you will be follow you'll be able to follow this video even on a 8GB CPU machine as well okay so we're going to set up Dy and we're going to also use AMA uh any of the new models like Lama 3.2 3B model okay and we're going to use it and see if we are able to set this up and ask some queries or do some task for us so let's jump in and see how we can do that if you look at here on my screen I am on AMA website if you don't know AMA as I said get up and running with llms that's what they have written over here on the website and you can just download I know it's like pretty easy to work with Okay you can download this on any one of the operating system so if you are on Mac OS if you are on Linux of you are on Windows you'll be able to use that okay now I am already on Windows and I have already installed it so I'm not going to do it again but if you are here click on this and just double click and install how can you find out if o Lama is running you see this icon over here it says o Lama right o Lama is running okay now if you want to find out a bit more let me open my terminal okay so if you look at here I'm opening my terminal and you can use command like o Lama list to find out if there are any models available you can see I have lot of models available Lama 3.2 3B Elijah which is a Japanese model it be nomic embedding I have an embedding model Lama 3.1 53 and Lama 3 I have these models that I mainly work with in day-to-day life you know for different tasks that I execute through these llms now how you can use this you have to for example you just have to write o Lama and then run and the model name if you want to download a model you have to do o Lama pull and the model name okay so you use P command to do that now here I'm I going to show you for example Lama 3.2 and 3B and after a few seconds you know it will show you where you can it will say send a message so basically you can ask your query so for example you want to write what is AI or let me say tell me a joke tell me a joke right I say tell me a joke it says here is one what do you call a fake noodle an impasta okay so you can see basically you can just ask a lot of questions over here right now AMA is also available through apis you know you can use uh Local Host and it's available on 11434 you can see it says AMA is running so you can use AMA through Lang chain Lama index or even in basic python through request module if you want to do that you know it's available on Port 11434 right 11,434 that's the port it runs on right now that's on AMA let me cover a bit about dii I have couple of videos on defi already on my channel Innovation engine for engine for Gen applications it's an open source development platform that's why I like about it if you look at other platforms like gum Loof for example or make they are making money for example they are not open source okay so uh nothing against them by the way but I ...

# %%
youtube_transcript_loader("https://www.youtube.com/watch?v=T4dsjsdfkldsjfer6ssp00k")
# Out:
# 'Error: \nCould not retrieve a transcript for the video https://www.youtube.com/watch?v=T4dsjsdfkldsjfer6ssp00k! This is most likely caused by:\n\nSubtitles are disabled for this video\n\nIf you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!'

# %%
from vyzeai.tools.prebuilt_tools import youtube_transcript_loader

tool = youtube_transcript_loader()

from vyzeai.models.openai import ChatOpenAI

llm = ChatOpenAI(tools=[tool], api_key="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")

# %%
llm.run("Extract transcript of the video: {https://www.youtube.com/watch?v=ovS83zHyhMs}")
# Out:
# Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_5Q0ut0pf3Sxs9jiv7S4JYOgt', function=Function(arguments='{"url":"https://www.youtube.com/watch?v=ovS83zHyhMs"}', name='youtube_transcript_loader'), type='function')], refusal=None))
# [ChatCompletionMessageToolCall(id='call_5Q0ut0pf3Sxs9jiv7S4JYOgt', function=Function(arguments='{"url":"https://www.youtube.com/watch?v=ovS83zHyhMs"}', name='youtube_transcript_loader'), type='function')]
# ["hello everyone welcome to AI anytime channel in this video we are going to see how we can use a no code platform called def aai with ol Lama earlier I have a video where I've shown how you can use Dy AI you know and geni Innovation engine a completely you know a low code no code platform where you can build jna applications faster and in that video I have shown with close Source models where you need an API key now for example if you want to use models like gp40 om mini you know Cloud models Gemini models Gro models so on and so forth so you need an API key over there to use that but you know most of the time you would not use these apis you want to use something which is open source where you can self host it you know where you can control everything you know mainly from a data confidentiality standpoint right because your data is confidential and you would not like to send that data to a third party company for example here the llm providers so how we can use o Lama a tool that basically helps you inference or run large language models locally in your machine you will be follow you'll be able to follow this video even on a 8GB CPU machine as well okay so we're going to set up Dy and we're going to also use AMA uh any of the new models like Lama 3.2 3B model okay and we're going to use it and see if we are able to set this up and ask some queries or do some task for us so let's jump in and see how we can do that if you look at here on my screen I am on AMA website if you don't know AMA as I said get up and running with llms that's what they have written over here on the website and you can just download I know it's like pretty easy to work with Okay you can download this on any one of the operating system so if you are on Mac OS if you are on Linux of you are on Windows you'll be able to use that okay now I am already on Windows and I have already installed it so I'm not going to do it again but if you are here click on this and just double click and install how can you find out if o Lama is running you see this icon over here it says o Lama right o Lama is running okay now if you want to find out a bit more let me open my terminal okay so if you look at here I'm opening my terminal and you can use command like o Lama list to find out if there are any models available you can see I have lot of models available Lama 3.2 3B Elijah which is a Japanese model it be nomic embedding I have an embedding model Lama 3.1 53 and Lama 3 I have these models that I mainly work with in day-to-day life you know for different tasks that I execute through these llms now how you can use this you have to for example you just have to write o Lama and then run and the model name if you want to download a model you have to do o Lama pull and the model name okay so you use P command to do that now here I'm I going to show you for example Lama 3.2 and 3B and after a few seconds you know it will show you where you can it will say send a message so basically you can ask your query so for example you want to write what is AI or let me say tell me a joke tell me a joke right I say tell me a joke it says here is one what do you call a fake noodle an impasta okay so you can see basically you can just ask a lot of questions over here right now AMA is also available through apis you know you can use uh Local Host and it's available on 11434 you can see it says AMA is running so you can use AMA through Lang chain Lama index or even in basic python through request module if you want to do that you know it's available on Port 11434 right 11,434 that's the port it runs on right now that's on AMA let me cover a bit about dii I have couple of videos on defi already on my channel Innovation engine for engine for Gen applications it's an open source development platform that's why I like about it if you look at other platforms like gum Loof for example or make they are making money for example they are not open source okay so uh nothing against them by the way but  ...
# ["hello everyone welcome to AI anytime channel in this video we are going to see how we can use a no code platform called def aai with ol Lama earlier I have a video where I've shown how you can use Dy AI you know and geni Innovation engine a completely you know a low code no code platform where you can build jna applications faster and in that video I have shown with close Source models where you need an API key now for example if you want to use models like gp40 om mini you know Cloud models Gemini models Gro models so on and so forth so you need an API key over there to use that but you know most of the time you would not use these apis you want to use something which is open source where you can self host it you know where you can control everything you know mainly from a data confidentiality standpoint right because your data is confidential and you would not like to send that data to a third party company for example here the llm providers so how we can use o Lama a tool that basically helps you inference or run large language models locally in your machine you will be follow you'll be able to follow this video even on a 8GB CPU machine as well okay so we're going to set up Dy and we're going to also use AMA uh any of the new models like Lama 3.2 3B model okay and we're going to use it and see if we are able to set this up and ask some queries or do some task for us so let's jump in and see how we can do that if you look at here on my screen I am on AMA website if you don't know AMA as I said get up and running with llms that's what they have written over here on the website and you can just download I know it's like pretty easy to work with Okay you can download this on any one of the operating system so if you are on Mac OS if you are on Linux of you are on Windows you'll be able to use that okay now I am already on Windows and I have already installed it so I'm not going to do it again but if you are here click on this and just double click and install how can you find out if o Lama is running you see this icon over here it says o Lama right o Lama is running okay now if you want to find out a bit more let me open my terminal okay so if you look at here I'm opening my terminal and you can use command like o Lama list to find out if there are any models available you can see I have lot of models available Lama 3.2 3B Elijah which is a Japanese model it be nomic embedding I have an embedding model Lama 3.1 53 and Lama 3 I have these models that I mainly work with in day-to-day life you know for different tasks that I execute through these llms now how you can use this you have to for example you just have to write o Lama and then run and the model name if you want to download a model you have to do o Lama pull and the model name okay so you use P command to do that now here I'm I going to show you for example Lama 3.2 and 3B and after a few seconds you know it will show you where you can it will say send a message so basically you can ask your query so for example you want to write what is AI or let me say tell me a joke tell me a joke right I say tell me a joke it says here is one what do you call a fake noodle an impasta okay so you can see basically you can just ask a lot of questions over here right now AMA is also available through apis you know you can use uh Local Host and it's available on 11434 you can see it says AMA is running so you can use AMA through Lang chain Lama index or even in basic python through request module if you want to do that you know it's available on Port 11434 right 11,434 that's the port it runs on right now that's on AMA let me cover a bit about dii I have couple of videos on defi already on my channel Innovation engine for engine for Gen applications it's an open source development platform that's why I like about it if you look at other platforms like gum Loof for example or make they are making money for example they are not open source okay so uh nothing against them by the way but  ...
# Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='Here\'s the transcript of the video titled "How to Use a No Code Platform with O Lama":\n\n---\n\n hello everyone welcome to AI anytime channel in this video we are going to see how we can use a no code platform called def aai with ol Lama earlier I have a video where I\'ve shown how you can use Dy AI you know and geni Innovation engine a completely you know a low code no code platform where you can build jna applications faster and in that video I have shown with close Source models where you need an API key now for example if you want to use models like gp40 om mini you know Cloud models Gemini models Gro models so on and so forth so you need an API key over there to use that but you know most of the time you would not use these apis you want to use something which is open source where you can self host it you know where you can control everything you know mainly from a data confidentiality standpoint right because your data is confidential and you would not like to send that data to a third party company for example here the llm providers so how we can use o Lama a tool that basically helps you inference or run large language models locally in your machine you will be follow you\'ll be able to follow this video even on a 8GB CPU machine as well okay so we\'re going to set up Dy and we\'re going to also use AMA uh any of the new models like Lama 3.2 3B model okay and we\'re going to use it and see if we are able to set this up and ask some queries or do some task for us so let\'s jump in and see how we can do that if you look at here on my screen I am on AMA website if you don\'t know AMA as I said get up and running with llms that\'s what they have written over here on the website and you can just download I know it\'s like pretty easy to work with Okay you can download this on any one of the operating system so if you are on Mac OS if you are on Linux of you are on Windows you\'ll be able to use that okay now I am already on Windows and I have already installed it so I\'m not going to do it again but if you are here click on this and just double click and install how can you find out if o Lama is running you see this icon over here it says o Lama right o Lama is running okay now if you want to find out a bit more let me open my terminal okay so if you look at here I\'m opening my terminal and you can use command like o Lama list to find out if there are any models available you can see I have lot of models available Lama 3.2 3B Elijah which is a Japanese model it be nomic embedding I have an embedding model Lama 3.1 53 and Lama 3 I have these models that I mainly work with in day-to-day life you know for different tasks that I execute through these llms now how you can use this you have to for example you just have to write o Lama and then run and the model name if you want to download a model you have to do o Lama pull and the model name okay so you use P command to do that now here I\'m I going to show you for example Lama 3.2 and 3B and after a few seconds you know it will show you where you can it will say send a message so basically you can ask your query so for example you want to write what is AI or let me say tell me a joke tell me a joke right I say tell me a joke it says here is one what do you call a fake noodle an impasta okay so you can see basically you can just ask a lot of questions over here right now AMA is also available through apis you know you can use uh Local Host and it\'s available on 11434 you can see it says AMA is running so you can use AMA through Lang chain Lama index or even in basic python through request module if you want to do that you know it\'s available on Port 11434 right 11,434 that\'s the port it runs on right now that\'s on AMA let me cover a bit about dii I have couple of videos on defi already on my channel Innovation engine for engine for Gen applications it\'s an open source development  ...
# ["hello everyone welcome to AI anytime channel in this video we are going to see how we can use a no code platform called def aai with ol Lama earlier I have a video where I've shown how you can use Dy AI you know and geni Innovation engine a completely you know a low code no code platform where you can build jna applications faster and in that video I have shown with close Source models where you need an API key now for example if you want to use models like gp40 om mini you know Cloud models Gemini models Gro models so on and so forth so you need an API key over there to use that but you know most of the time you would not use these apis you want to use something which is open source where you can self host it you know where you can control everything you know mainly from a data confidentiality standpoint right because your data is confidential and you would not like to send that data to a third party company for example here the llm providers so how we can use o Lama a tool that basically helps you inference or run large language models locally in your machine you will be follow you'll be able to follow this video even on a 8GB CPU machine as well okay so we're going to set up Dy and we're going to also use AMA uh any of the new models like Lama 3.2 3B model okay and we're going to use it and see if we are able to set this up and ask some queries or do some task for us so let's jump in and see how we can do that if you look at here on my screen I am on AMA website if you don't know AMA as I said get up and running with llms that's what they have written over here on the website and you can just download I know it's like pretty easy to work with Okay you can download this on any one of the operating system so if you are on Mac OS if you are on Linux of you are on Windows you'll be able to use that okay now I am already on Windows and I have already installed it so I'm not going to do it again but if you are here click on this and just double click and install how can you find out if o Lama is running you see this icon over here it says o Lama right o Lama is running okay now if you want to find out a bit more let me open my terminal okay so if you look at here I'm opening my terminal and you can use command like o Lama list to find out if there are any models available you can see I have lot of models available Lama 3.2 3B Elijah which is a Japanese model it be nomic embedding I have an embedding model Lama 3.1 53 and Lama 3 I have these models that I mainly work with in day-to-day life you know for different tasks that I execute through these llms now how you can use this you have to for example you just have to write o Lama and then run and the model name if you want to download a model you have to do o Lama pull and the model name okay so you use P command to do that now here I'm I going to show you for example Lama 3.2 and 3B and after a few seconds you know it will show you where you can it will say send a message so basically you can ask your query so for example you want to write what is AI or let me say tell me a joke tell me a joke right I say tell me a joke it says here is one what do you call a fake noodle an impasta okay so you can see basically you can just ask a lot of questions over here right now AMA is also available through apis you know you can use uh Local Host and it's available on 11434 you can see it says AMA is running so you can use AMA through Lang chain Lama index or even in basic python through request module if you want to do that you know it's available on Port 11434 right 11,434 that's the port it runs on right now that's on AMA let me cover a bit about dii I have couple of videos on defi already on my channel Innovation engine for engine for Gen applications it's an open source development platform that's why I like about it if you look at other platforms like gum Loof for example or make they are making money for example they are not open source okay so uh nothing against them by the way but  ...

# %%
llm.run("Extract transcript of the video: {https://www.youtube.com/watch?v=ovS83zHyhMs}", return_tool_output=True)
# Out:
# Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_yJltWRf5CTlhnALLk0CZbhEc', function=Function(arguments='{"url":"https://www.youtube.com/watch?v=ovS83zHyhMs"}', name='youtube_transcript_loader'), type='function')], refusal=None))
# [ChatCompletionMessageToolCall(id='call_yJltWRf5CTlhnALLk0CZbhEc', function=Function(arguments='{"url":"https://www.youtube.com/watch?v=ovS83zHyhMs"}', name='youtube_transcript_loader'), type='function')]
# ["hello everyone welcome to AI anytime channel in this video we are going to see how we can use a no code platform called def aai with ol Lama earlier I have a video where I've shown how you can use Dy AI you know and geni Innovation engine a completely you know a low code no code platform where you can build jna applications faster and in that video I have shown with close Source models where you need an API key now for example if you want to use models like gp40 om mini you know Cloud models Gemini models Gro models so on and so forth so you need an API key over there to use that but you know most of the time you would not use these apis you want to use something which is open source where you can self host it you know where you can control everything you know mainly from a data confidentiality standpoint right because your data is confidential and you would not like to send that data to a third party company for example here the llm providers so how we can use o Lama a tool that basically helps you inference or run large language models locally in your machine you will be follow you'll be able to follow this video even on a 8GB CPU machine as well okay so we're going to set up Dy and we're going to also use AMA uh any of the new models like Lama 3.2 3B model okay and we're going to use it and see if we are able to set this up and ask some queries or do some task for us so let's jump in and see how we can do that if you look at here on my screen I am on AMA website if you don't know AMA as I said get up and running with llms that's what they have written over here on the website and you can just download I know it's like pretty easy to work with Okay you can download this on any one of the operating system so if you are on Mac OS if you are on Linux of you are on Windows you'll be able to use that okay now I am already on Windows and I have already installed it so I'm not going to do it again but if you are here click on this and just double click and install how can you find out if o Lama is running you see this icon over here it says o Lama right o Lama is running okay now if you want to find out a bit more let me open my terminal okay so if you look at here I'm opening my terminal and you can use command like o Lama list to find out if there are any models available you can see I have lot of models available Lama 3.2 3B Elijah which is a Japanese model it be nomic embedding I have an embedding model Lama 3.1 53 and Lama 3 I have these models that I mainly work with in day-to-day life you know for different tasks that I execute through these llms now how you can use this you have to for example you just have to write o Lama and then run and the model name if you want to download a model you have to do o Lama pull and the model name okay so you use P command to do that now here I'm I going to show you for example Lama 3.2 and 3B and after a few seconds you know it will show you where you can it will say send a message so basically you can ask your query so for example you want to write what is AI or let me say tell me a joke tell me a joke right I say tell me a joke it says here is one what do you call a fake noodle an impasta okay so you can see basically you can just ask a lot of questions over here right now AMA is also available through apis you know you can use uh Local Host and it's available on 11434 you can see it says AMA is running so you can use AMA through Lang chain Lama index or even in basic python through request module if you want to do that you know it's available on Port 11434 right 11,434 that's the port it runs on right now that's on AMA let me cover a bit about dii I have couple of videos on defi already on my channel Innovation engine for engine for Gen applications it's an open source development platform that's why I like about it if you look at other platforms like gum Loof for example or make they are making money for example they are not open source okay so uh nothing against them by the way but  ...
# ["hello everyone welcome to AI anytime channel in this video we are going to see how we can use a no code platform called def aai with ol Lama earlier I have a video where I've shown how you can use Dy AI you know and geni Innovation engine a completely you know a low code no code platform where you can build jna applications faster and in that video I have shown with close Source models where you need an API key now for example if you want to use models like gp40 om mini you know Cloud models Gemini models Gro models so on and so forth so you need an API key over there to use that but you know most of the time you would not use these apis you want to use something which is open source where you can self host it you know where you can control everything you know mainly from a data confidentiality standpoint right because your data is confidential and you would not like to send that data to a third party company for example here the llm providers so how we can use o Lama a tool that basically helps you inference or run large language models locally in your machine you will be follow you'll be able to follow this video even on a 8GB CPU machine as well okay so we're going to set up Dy and we're going to also use AMA uh any of the new models like Lama 3.2 3B model okay and we're going to use it and see if we are able to set this up and ask some queries or do some task for us so let's jump in and see how we can do that if you look at here on my screen I am on AMA website if you don't know AMA as I said get up and running with llms that's what they have written over here on the website and you can just download I know it's like pretty easy to work with Okay you can download this on any one of the operating system so if you are on Mac OS if you are on Linux of you are on Windows you'll be able to use that okay now I am already on Windows and I have already installed it so I'm not going to do it again but if you are here click on this and just double click and install how can you find out if o Lama is running you see this icon over here it says o Lama right o Lama is running okay now if you want to find out a bit more let me open my terminal okay so if you look at here I'm opening my terminal and you can use command like o Lama list to find out if there are any models available you can see I have lot of models available Lama 3.2 3B Elijah which is a Japanese model it be nomic embedding I have an embedding model Lama 3.1 53 and Lama 3 I have these models that I mainly work with in day-to-day life you know for different tasks that I execute through these llms now how you can use this you have to for example you just have to write o Lama and then run and the model name if you want to download a model you have to do o Lama pull and the model name okay so you use P command to do that now here I'm I going to show you for example Lama 3.2 and 3B and after a few seconds you know it will show you where you can it will say send a message so basically you can ask your query so for example you want to write what is AI or let me say tell me a joke tell me a joke right I say tell me a joke it says here is one what do you call a fake noodle an impasta okay so you can see basically you can just ask a lot of questions over here right now AMA is also available through apis you know you can use uh Local Host and it's available on 11434 you can see it says AMA is running so you can use AMA through Lang chain Lama index or even in basic python through request module if you want to do that you know it's available on Port 11434 right 11,434 that's the port it runs on right now that's on AMA let me cover a bit about dii I have couple of videos on defi already on my channel Innovation engine for engine for Gen applications it's an open source development platform that's why I like about it if you look at other platforms like gum Loof for example or make they are making money for example they are not open source okay so uh nothing against them by the way but  ...
